# %%
import cv2

# %%
import numpy

# %%
img=cv2.imread(r"C:\Python35\images\dhoni124.jpg")

# %%
img.shape
# Out:
# (540, 484, 3)

# %%
cv2.imshow('img',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img2=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
import matplotlib.pyplot as plt
plt.imshow(img2)
plt.show()

# %%
img3=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img3,cmap='gray')
plt.show()

# %%
img4=cv2.imread(r"C:\Python35\images\dhoni124.jpg",1)
img4.shape
# Out:
# (540, 484, 3)

# %%
plt.imshow(img4[:300,200:])
plt.show()

# %%
# take an image from a video stream using openCV

# %%
import time

# %%
vid=cv2.VideoCapture(r"C:\Users\Roboindia\Downloads\Virat Kohli & MS Dhoni enjoy their time during net sessions at Dambulla.mp4")
time.sleep(100)
ret,img=vid.read()
cv2.imshow('img',img)
cv2.waitKey(0)
vid.release()
cv2.destroyAllWindows()
