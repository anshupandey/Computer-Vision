# %% [markdown]
# <a href="https://colab.research.google.com/github/anshupandey/Computer-Vision/blob/master/Autoencoders/Autoencoder_for_dimensionality_reduction_and_image_denoising.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Autoencoders for Image compression

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.datasets import mnist
from tensorflow.keras import models,layers

# %% [markdown]
# ## Data Preparation

# %%
#load the MNIST dataset
(xtrain,ytrain),(xtest,ytest) = mnist.load_data()
print(xtrain.shape)
print(xtest.shape)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 11501568/11490434 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (10000, 28, 28)

# %%
xtrain = xtrain/255
xtest = xtest/255

# %%
print(xtrain.shape)
print(xtest.shape)
xtrain = xtrain.reshape(60000,28*28)
xtest = xtest.reshape(10000,28*28)
print(xtrain.shape)
print(xtest.shape)
# Out:
# (60000, 28, 28)
# (10000, 28, 28)
# (60000, 784)
# (10000, 784)

# %% [markdown]
# ## Modelling

# %%
# Encoder
input_layer = layers.Input(shape=(784,))
dense1 = layers.Dense(128,activation='relu')(input_layer)

dense2 = layers.Dense(64,activation='relu')(dense1)

# Decoder 
dense3 = layers.Dense(128,activation='relu')(dense2)
output_layer = layers.Dense(784,activation='sigmoid')(dense3)
model = models.Model(input_layer,output_layer)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               8320
# _________________________________________________________________
# dense_3 (Dense)              (None, 784)               101136
# =================================================================
# Total params: 218,192
# Trainable params: 218,192
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer='adam',loss='binary_crossentropy',metrics=['accuracy'])
model.fit(xtrain,xtrain,epochs=30,batch_size=128,shuffle=True,validation_data=(xtest,xtest))
# Out:
# Epoch 1/30
# 469/469 [==============================] - 5s 5ms/step - loss: 0.1794 - accuracy: 0.0112 - val_loss: 0.1156 - val_accuracy: 0.0095
# Epoch 2/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.1064 - accuracy: 0.0099 - val_loss: 0.0971 - val_accuracy: 0.0121
# Epoch 3/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0953 - accuracy: 0.0122 - val_loss: 0.0912 - val_accuracy: 0.0116
# Epoch 4/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0906 - accuracy: 0.0129 - val_loss: 0.0877 - val_accuracy: 0.0130
# Epoch 5/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0873 - accuracy: 0.0133 - val_loss: 0.0848 - val_accuracy: 0.0125
# Epoch 6/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0848 - accuracy: 0.0138 - val_loss: 0.0829 - val_accuracy: 0.0140
# Epoch 7/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0829 - accuracy: 0.0136 - val_loss: 0.0813 - val_accuracy: 0.0128
# Epoch 8/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0814 - accuracy: 0.0132 - val_loss: 0.0797 - val_accuracy: 0.0130
# Epoch 9/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0801 - accuracy: 0.0135 - val_loss: 0.0790 - val_accuracy: 0.0123
# Epoch 10/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0792 - accuracy: 0.0137 - val_loss: 0.0779 - val_accuracy: 0.0121
# Epoch 11/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0784 - accuracy: 0.0133 - val_loss: 0.0775 - val_accuracy: 0.0137
# Epoch 12/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0778 - accuracy: 0.0130 - val_loss: 0.0767 - val_accuracy: 0.0131
# Epoch 13/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0772 - accuracy: 0.0135 - val_loss: 0.0761 - val_accuracy: 0.0126
# Epoch 14/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0768 - accuracy: 0.0134 - val_loss: 0.0761 - val_accuracy: 0.0128
# Epoch 15/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0764 - accuracy: 0.0136 - val_loss: 0.0754 - val_accuracy: 0.0117
# Epoch 16/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0760 - accuracy: 0.0145 - val_loss: 0.0758 - val_accuracy: 0.0145
# Epoch 17/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0757 - accuracy: 0.0140 - val_loss: 0.0750 - val_accuracy: 0.0128
# Epoch 18/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0753 - accuracy: 0.0133 - val_loss: 0.0745 - val_accuracy: 0.0145
# Epoch 19/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0750 - accuracy: 0.0141 - val_loss: 0.0743 - val_accuracy: 0.0142
# Epoch 20/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0747 - accuracy: 0.0138 - val_loss: 0.0740 - val_accuracy: 0.0144
# Epoch 21/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0745 - accuracy: 0.0146 - val_loss: 0.0740 - val_accuracy: 0.0125
# Epoch 22/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0743 - accuracy: 0.0139 - val_loss: 0.0735 - val_accuracy: 0.0131
# Epoch 23/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0740 - accuracy: 0.0142 - val_loss: 0.0736 - val_accuracy: 0.0134
# Epoch 24/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0738 - accuracy: 0.0138 - val_loss: 0.0733 - val_accuracy: 0.0142
# Epoch 25/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0737 - accuracy: 0.0140 - val_loss: 0.0730 - val_accuracy: 0.0131
# Epoch 26/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0735 - accuracy: 0.0143 - val_loss: 0.0730 - val_accuracy: 0.0119
# Epoch 27/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0733 - accuracy: 0.0140 - val_loss: 0.0729 - val_accuracy: 0.0146
# Epoch 28/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0732 - accuracy: 0.0145 - val_loss: 0.0729 - val_accuracy: 0.0137
# Epoch 29/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0730 - accuracy: 0.0142 - val_loss: 0.0726 - val_accuracy: 0.0130
# Epoch 30/30
# 469/469 [==============================] - 2s 5ms/step - loss: 0.0729 - accuracy: 0.0141 - val_loss: 0.0724 - val_accuracy: 0.0141

# %%
encoder = models.Model(input_layer,dense2)
encoder.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 784)]             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               100480
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# =================================================================
# Total params: 108,736
# Trainable params: 108,736
# Non-trainable params: 0
# _________________________________________________________________

# %%
encodop = encoder.predict(xtest)
print(encodop.shape)
prediction = model.predict(xtest)
print(prediction.shape)
# Out:
# (10000, 64)
# (10000, 784)

# %%
n = 10
for i in range(n):
  plt.figure(figsize=(12,4))
  plt.subplot(131)
  plt.title("Original image")
  plt.imshow(xtest[i].reshape(28,28),cmap='gray')
  plt.subplot(132)
  plt.title("compressed image")
  plt.imshow(encodop[i].reshape(8,8),cmap='gray')
  plt.subplot(133)
  plt.title("Reconstructed image")
  plt.imshow(prediction[i].reshape(28,28),cmap='gray')
  plt.show()

# %% [markdown]
# ## Autoencoders for denoising images

# %%
#load the MNIST dataset
(xtrain,ytrain),(xtest,ytest) = mnist.load_data()
#scaling the images
xtrain = (xtrain - 127.5) / 127.5
xtest = (xtest - 127.5) / 127.5
# reshaping images to channel format - samples,row,cols,channels
xtrain = xtrain.reshape(60000,28,28,1)
xtest = xtest.reshape(10000,28,28,1)
print(xtrain.shape)
print(xtest.shape)
# Out:
# (60000, 28, 28, 1)
# (10000, 28, 28, 1)

# %%
input_layer = layers.Input(shape=(28,28,1))
c1 = layers.Conv2D(16,(3,3),activation='relu',padding='same',strides=(2,2))(input_layer)
c2 = layers.Conv2D(8,(3,3),activation='relu',padding='same',strides=(2,2))(c1)

c3 = layers.Conv2DTranspose(8,(3,3),activation='relu',padding='same',strides=(2,2))(c2)
c4 = layers.Conv2DTranspose(16,(3,3),activation='relu',padding='same',strides=(2,2))(c3)
output_layer = layers.Conv2D(1,(3,3),activation='tanh',padding='same')(c4)

model = models.Model(input_layer,output_layer)
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 28, 28, 1)]       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 14, 14, 16)        160
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 7, 7, 8)           1160
# _________________________________________________________________
# conv2d_transpose (Conv2DTran (None, 14, 14, 8)         584
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 28, 28, 16)        1168
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 28, 28, 1)         145
# =================================================================
# Total params: 3,217
# Trainable params: 3,217
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras import losses
model.compile(optimizer='adam',loss=losses.MeanSquaredError())

# %%
import tensorflow as tf
noise_factor = 0.4
xtrain_noisy = xtrain + noise_factor * tf.random.normal(shape=xtrain.shape)
xtest_noisy = xtest + noise_factor * tf.random.normal(shape=xtest.shape)

xtrain_noisy = tf.clip_by_value(xtrain_noisy,-1.0,1.0) 
xtest_noisy = tf.clip_by_value(xtest_noisy,-1.0,1.0)

# %%
n=10
plt.figure(figsize=(20,3))
for i in range(n):
  plt.subplot(1,n,i+1)
  plt.imshow(tf.squeeze(xtrain_noisy[i]),cmap='gray')
plt.show()

# %%
model.fit(xtrain_noisy,xtrain,epochs=20,batch_size=1000,shuffle=True,validation_data=(xtest_noisy,xtest))
# Out:
# Epoch 1/20
# 60/60 [==============================] - 29s 49ms/step - loss: 0.5543 - val_loss: 0.2706
# Epoch 2/20
# 60/60 [==============================] - 2s 41ms/step - loss: 0.2080 - val_loss: 0.1631
# Epoch 3/20
# 60/60 [==============================] - 2s 41ms/step - loss: 0.1079 - val_loss: 0.0645
# Epoch 4/20
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0525 - val_loss: 0.0422
# Epoch 5/20
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0384 - val_loss: 0.0339
# Epoch 6/20
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0325 - val_loss: 0.0297
# Epoch 7/20
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0268 - val_loss: 0.0235
# Epoch 8/20
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0229 - val_loss: 0.0213
# Epoch 9/20
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0212 - val_loss: 0.0202
# Epoch 10/20
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0201 - val_loss: 0.0192
# Epoch 11/20
# 60/60 [==============================] - 3s 44ms/step - loss: 0.0193 - val_loss: 0.0185
# Epoch 12/20
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0186 - val_loss: 0.0180
# Epoch 13/20
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0181 - val_loss: 0.0175
# Epoch 14/20
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0176 - val_loss: 0.0171
# Epoch 15/20
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0173 - val_loss: 0.0168
# Epoch 16/20
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0170 - val_loss: 0.0165
# Epoch 17/20
# 60/60 [==============================] - 2s 40ms/step - loss: 0.0167 - val_loss: 0.0163
# Epoch 18/20
# 60/60 [==============================] - 3s 43ms/step - loss: 0.0165 - val_loss: 0.0161
# Epoch 19/20
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0163 - val_loss: 0.0159
# Epoch 20/20
# 60/60 [==============================] - 2s 41ms/step - loss: 0.0161 - val_loss: 0.0158

# %%
prediction = model.predict(xtest_noisy)
prediction.shape
# Out:
# (10000, 28, 28, 1)

# %%
n = 10
for i in range(10):
  plt.subplot(121)
  plt.imshow(tf.squeeze(xtest_noisy[i]),cmap='gray')
  plt.subplot(122)
  plt.imshow(prediction[i].reshape(28,28),cmap='gray')
  plt.show()
