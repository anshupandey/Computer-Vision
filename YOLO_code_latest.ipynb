# %% [markdown]
# <a href="https://colab.research.google.com/github/anshupandey/Computer-Vision/blob/master/YOLO_code_latest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **YOLO**

# %% [markdown]
# # Installing Darknet

# %%
# !git clone https://github.com/AlexeyAB/darknet
import os
os.chdir("/content/darknet")
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 14730, done.
# remote: Total 14730 (delta 0), reused 0 (delta 0), pack-reused 14730
# Receiving objects: 100% (14730/14730), 13.25 MiB | 24.67 MiB/s, done.
# Resolving deltas: 100% (10018/10018), done.

# %%
# Compiling darknet
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !cat Makefile
# !make
# Out:
# GPU=1
# CUDNN=0
# CUDNN_HALF=0
# OPENCV=0
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
# ZED_CAMERA_v2_8=0
#
# # set GPU=1 and CUDNN=1 to speedup on GPU
# # set CUDNN_HALF=1 to further speedup 3 x times (Mixed-precision on Tensor Cores) GPU: Volta, Xavier, Turing and higher
# # set AVX=1 and OPENMP=1 to speedup on CPU (if error occurs then set AVX=0)
# # set ZED_CAMERA=1 to enable ZED SDK 3.0 and above
# # set ZED_CAMERA_v2_8=1 to enable ZED SDK 2.X
#
# USE_CPP=0
# DEBUG=0
#
# ARCH= -gencode arch=compute_35,code=sm_35 \
#       -gencode arch=compute_50,code=[sm_50,compute_50] \
#       -gencode arch=compute_52,code=[sm_52,compute_52] \
# 	    -gencode arch=compute_61,code=[sm_61,compute_61]
#
# OS := $(shell uname)
#
# # GeForce RTX 3070, 3080, 3090
# # ARCH= -gencode arch=compute_86,code=[sm_86,compute_86]
#
# # Kepler GeForce GTX 770, GTX 760, GT 740
# # ARCH= -gencode arch=compute_30,code=sm_30
#
# # Tesla A100 (GA100), DGX-A100, RTX 3080
# # ARCH= -gencode arch=compute_80,code=[sm_80,compute_80]
#
# # Tesla V100
# # ARCH= -gencode arch=compute_70,code=[sm_70,compute_70]
#
# # GeForce RTX 2080 Ti, RTX 2080, RTX 2070, Quadro RTX 8000, Quadro RTX 6000, Quadro RTX 5000, Tesla T4, XNOR Tensor Cores
# # ARCH= -gencode arch=compute_75,code=[sm_75,compute_75]
#
# # Jetson XAVIER
# # ARCH= -gencode arch=compute_72,code=[sm_72,compute_72]
#
# # GTX 1080, GTX 1070, GTX 1060, GTX 1050, GTX 1030, Titan Xp, Tesla P40, Tesla P4
# # ARCH= -gencode arch=compute_61,code=sm_61 -gencode arch=compute_61,code=compute_61
#
# # GP100/Tesla P100 - DGX-1
# # ARCH= -gencode arch=compute_60,code=sm_60
#
# # For Jetson TX1, Tegra X1, DRIVE CX, DRIVE PX - uncomment:
# # ARCH= -gencode arch=compute_53,code=[sm_53,compute_53]
#
# # For Jetson Tx2 or Drive-PX2 uncomment:
# # ARCH= -gencode arch=compute_62,code=[sm_62,compute_62]
#
# # For Tesla GA10x cards, RTX 3090, RTX 3080, RTX 3070, RTX A6000, RTX A40 uncomment:
# # ARCH= -gencode arch=compute_86,code=[sm_86,compute_86]
#
#
# VPATH=./src/
# EXEC=darknet
# OBJDIR=./obj/
#
# ifeq ($(LIBSO), 1)
# LIBNAMESO=libdarknet.so
# APPNAMESO=uselib
# endif
#
# ifeq ($(USE_CPP), 1)
# CC=g++
# else
# CC=gcc
# endif
#
# CPP=g++ -std=c++11
# NVCC=nvcc
# OPTS=-Ofast
# LDFLAGS= -lm -pthread
# COMMON= -Iinclude/ -I3rdparty/stb/include
# CFLAGS=-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC
#
# ifeq ($(DEBUG), 1)
# #OPTS= -O0 -g
# #OPTS= -Og -g
# COMMON+= -DDEBUG
# CFLAGS+= -DDEBUG
# else
# ifeq ($(AVX), 1)
# CFLAGS+= -ffp-contract=fast -mavx -mavx2 -msse3 -msse4.1 -msse4.2 -msse4a
# endif
# endif
#
# CFLAGS+=$(OPTS)
#
# ifneq (,$(findstring MSYS_NT,$(OS)))
# LDFLAGS+=-lws2_32
# endif
#
# ifeq ($(OPENCV), 1)
# COMMON+= -DOPENCV
# CFLAGS+= -DOPENCV
# LDFLAGS+= `pkg-config --libs opencv4 2> /dev/null || pkg-config --libs opencv`
# COMMON+= `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv`
# endif
#
# ifeq ($(OPENMP), 1)
#     ifeq ($(OS),Darwin) #MAC
# 	    CFLAGS+= -Xpreprocessor -fopenmp
# 	else
# 		CFLAGS+= -fopenmp
# 	endif
# LDFLAGS+= -lgomp
# endif
#
# ifeq ($(GPU), 1)
# COMMON+= -DGPU -I/usr/local/cuda/include/
# CFLAGS+= -DGPU
# ifeq ($(OS),Darwin) #MAC
# LDFLAGS+= -L/usr/local/cuda/lib -lcuda -lcudart -lcublas -lcurand
# else
# LDFLAGS+= -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand
# endif
# endif
#
# ifeq ($(CUDNN), 1)
# COMMON+= -DCUDNN
# ifeq ($(OS),Darwin) #MAC
# CFLAGS+= -DCUDNN -I/usr/local/cuda/include
# LDFLAGS+= -L/usr/local/cuda/lib -lcudnn
# else
# CFLAGS+= -DCUDNN -I/usr/local/cudnn/include
# LDFLAGS+= -L/usr/local/cudnn/lib64 -lcudnn
# endif
# endif
#
# ifeq ($(CUDNN_HALF), 1)
# COMMON+= -DCUDNN_HALF
# CFLAGS+= -DCUDNN_HALF
# ARCH+= -gencode arch=compute_70,code=[sm_70,compute_70]
# endif
#
# ifeq ($(ZED_CAMERA), 1)
# CFLAGS+= -DZED_STEREO -I/usr/local/zed/include
# ifeq ($(ZED_CAMERA_v2_8), 1)
# LDFLAGS+= -L/usr/local/zed/lib -lsl_core -lsl_input -lsl_zed
# #-lstdc++ -D_GLIBCXX_USE_CXX11_ABI=0
# else
# LDFLAGS+= -L/usr/local/zed/lib -lsl_zed
# #-lstdc++ -D_GLIBCXX_USE_CXX11_ABI=0
# endif
# endif
#
# OBJ=image_opencv.o http_stream.o gemm.o utils.o dark_cuda.o convolutional_layer.o list.o image.o activations.o im2col.o col2im.o blas.o crop_layer.o dropout_layer.o maxpool_layer.o softmax_layer.o data.o matrix.o network.o connected_layer.o cost_layer.o parser.o option_list.o darknet.o detection_layer.o captcha.o route_layer.o writing.o box.o nightmare.o normalization_layer.o avgpool_layer.o coco.o dice.o yolo.o detector.o layer.o compare.o classifier.o local_layer.o swag.o shortcut_layer.o activation_layer.o rnn_layer.o gru_layer.o rnn.o rnn_vid.o crnn_layer.o demo.o tag.o cifar.o go.o batchnorm_layer.o art.o region_layer.o reorg_layer.o reorg_old_layer.o super.o voxel.o tree.o yolo_layer.o gaussian_yolo_layer.o upsample_layer.o lstm_layer.o conv_lstm_layer.o scale_channels_layer.o sam_layer.o
# ifeq ($(GPU), 1)
# LDFLAGS+= -lstdc++
# OBJ+=convolutional_kernels.o activation_kernels.o im2col_kernels.o col2im_kernels.o blas_kernels.o crop_layer_kernels.o dropout_layer_kernels.o maxpool_layer_kernels.o network_kernels.o avgpool_layer_kernels.o
# endif
#
# OBJS = $(addprefix $(OBJDIR), $(OBJ))
# DEPS = $(wildcard src/*.h) Makefile include/darknet.h
#
# all: $(OBJDIR) backup results setchmod $(EXEC) $(LIBNAMESO) $(APPNAMESO)
#
# ifeq ($(LIBSO), 1)
# CFLAGS+= -fPIC
#
# $(LIBNAMESO): $(OBJDIR) $(OBJS) include/yolo_v2_class.hpp src/yolo_v2_class.cpp
# 	$(CPP) -shared -std=c++11 -fvisibility=hidden -DLIB_EXPORTS $(COMMON) $(CFLAGS) $(OBJS) src/yolo_v2_class.cpp -o $@ $(LDFLAGS)
#
# $(APPNAMESO): $(LIBNAMESO) include/yolo_v2_class.hpp src/yolo_console_dll.cpp
# 	$(CPP) -std=c++11 $(COMMON) $(CFLAGS) -o $@ src/yolo_console_dll.cpp $(LDFLAGS) -L ./ -l:$(LIBNAMESO)
# endif
#
# $(EXEC): $(OBJS)
# 	$(CPP) -std=c++11 $(COMMON) $(CFLAGS) $^ -o $@ $(LDFLAGS)
#
# $(OBJDIR)%.o: %.c $(DEPS)
# 	$(CC) $(COMMON) $(CFLAGS) -c $< -o $@
#
# $(OBJDIR)%.o: %.cpp $(DEPS)
# 	$(CPP) -std=c++11 $(COMMON) $(CFLAGS) -c $< -o $@
#
# $(OBJDIR)%.o: %.cu $(DEPS)
# 	$(NVCC) $(ARCH) $(COMMON) --compiler-options "$(CFLAGS)" -c $< -o $@
#
# $(OBJDIR):
# 	mkdir -p $(OBJDIR)
# backup:
# 	mkdir -p backup
# results:
# 	mkdir -p results
# setchmod:
# 	chmod +x *.sh
#
# .PHONY: clean
#
# clean:
# 	rm -rf $(OBJS) $(EXEC) $(LIBNAMESO) $(APPNAMESO)
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/image_opencv.cpp -o obj/image_opencv.o
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/http_stream.cpp -o obj/http_stream.o
# ./src/http_stream.cpp: In member function ‘bool JSON_sender::write(const char*)’:
# ./src/http_stream.cpp:249:21: warning: unused variable ‘n’ [-Wunused-variable]
#                  int n = _write(client, outputbuf, outlen);
#                      ^
# ./src/http_stream.cpp: In function ‘void set_track_id(detection*, int, float, float, float, int, int, int)’:
# ./src/http_stream.cpp:863:27: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#          for (int i = 0; i < v.size(); ++i) {
#                          ~~^~~~~~~~~~
# ./src/http_stream.cpp:871:33: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int old_id = 0; old_id < old_dets.size(); ++old_id) {
#                           ~~~~~~~^~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:890:31: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      for (int index = 0; index < new_dets_num*old_dets.size(); ++index) {
#                          ~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/http_stream.cpp:926:28: warning: comparison between signed and unsigned integer expressions [-Wsign-compare]
#      if (old_dets_dq.size() > deque_size) old_dets_dq.pop_front();
#          ~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/gemm.c -o obj/gemm.o
# ./src/gemm.c: In function ‘convolution_2d’:
# ./src/gemm.c:2038:15: warning: unused variable ‘out_w’ [-Wunused-variable]
#      const int out_w = (w + 2 * pad - ksize) / stride + 1;    // output_width=input_width for stride=1 and pad=1
#                ^~~~~
# ./src/gemm.c:2037:15: warning: unused variable ‘out_h’ [-Wunused-variable]
#      const int out_h = (h + 2 * pad - ksize) / stride + 1;    // output_height=input_height for stride=1 and pad=1
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/utils.c -o obj/utils.o
# ./src/utils.c: In function ‘custom_hash’:
# ./src/utils.c:1045:12: warning: suggest parentheses around assignment used as truth value [-Wparentheses]
#      while (c = *str++)
#             ^
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/dark_cuda.c -o obj/dark_cuda.o
# ./src/dark_cuda.c:306:14: warning: type defaults to ‘int’ in declaration of ‘max_events’ [-Wimplicit-int]
#  static const max_events = 1024;
#               ^~~~~~~~~~
# ./src/dark_cuda.c: In function ‘pre_allocate_pinned_memory’:
# ./src/dark_cuda.c:364:40: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                       ~~^
#                                       %Ilu
#              size / (1024*1024), num_of_blocks, pinned_block_size / (1024 * 1024));
#              ~~~~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:364:64: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 3 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                               ~~^
#                                                               %Ilu
# ./src/dark_cuda.c:364:82: warning: format ‘%u’ expects argument of type ‘unsigned int’, but argument 4 has type ‘long unsigned int’ [-Wformat=]
#          printf("pre_allocate: size = %Iu MB, num_of_blocks = %Iu, block_size = %Iu MB \n",
#                                                                                 ~~^
#                                                                                 %Ilu
# ./src/dark_cuda.c:374:37: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#                  printf(" Allocated %d pinned block \n", pinned_block_size);
#                                     ~^
#                                     %ld
# ./src/dark_cuda.c: In function ‘cuda_make_array_pinned_preallocated’:
# ./src/dark_cuda.c:395:43: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#              printf("\n Pinned block_id = %d, filled = %f %% \n", pinned_block_id, filled);
#                                           ~^
#                                           %ld
# ./src/dark_cuda.c:410:64: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned memory, size = %d MB \n", size / (1024 * 1024));
#                                                                ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                                %ld
# ./src/dark_cuda.c:416:63: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘long unsigned int’ [-Wformat=]
#              printf("Try to allocate new pinned BLOCK, size = %d MB \n", size / (1024 * 1024));
#                                                               ~^         ~~~~~~~~~~~~~~~~~~~~
#                                                               %ld
# At top level:
# ./src/dark_cuda.c:256:23: warning: ‘switchBlasHandle’ defined but not used [-Wunused-variable]
#  static cublasHandle_t switchBlasHandle[16];
#                        ^~~~~~~~~~~~~~~~
# ./src/dark_cuda.c:255:12: warning: ‘switchBlasInit’ defined but not used [-Wunused-variable]
#  static int switchBlasInit[16] = { 0 };
#             ^~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/convolutional_layer.c -o obj/convolutional_layer.o
# ./src/convolutional_layer.c: In function ‘forward_convolutional_layer’:
# ./src/convolutional_layer.c:1341:32: warning: unused variable ‘t_intput_size’ [-Wunused-variable]
#                          size_t t_intput_size = binary_transpose_align_input(k, n, state.workspace, &l.t_bit_input, ldb_align, l.bit_align);
#                                 ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/list.c -o obj/list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/image.c -o obj/image.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/activations.c -o obj/activations.o
# ./src/activations.c: In function ‘activate’:
# ./src/activations.c:79:5: warning: enumeration value ‘RELU6’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:79:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX’ not handled in switch [-Wswitch]
# ./src/activations.c:79:5: warning: enumeration value ‘NORM_CHAN_SOFTMAX_MAXVAL’ not handled in switch [-Wswitch]
# ./src/activations.c: In function ‘gradient’:
# ./src/activations.c:310:5: warning: enumeration value ‘SWISH’ not handled in switch [-Wswitch]
#      switch(a){
#      ^~~~~~
# ./src/activations.c:310:5: warning: enumeration value ‘MISH’ not handled in switch [-Wswitch]
# ./src/activations.c:310:5: warning: enumeration value ‘HARD_MISH’ not handled in switch [-Wswitch]
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/im2col.c -o obj/im2col.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/col2im.c -o obj/col2im.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/blas.c -o obj/blas.o
# ./src/blas.c: In function ‘backward_shortcut_multilayer_cpu’:
# ./src/blas.c:207:21: warning: unused variable ‘out_index’ [-Wunused-variable]
#                  int out_index = id;
#                      ^~~~~~~~~
# ./src/blas.c: In function ‘find_sim’:
# ./src/blas.c:597:59: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                           ~^
#                                                           %ld
# ./src/blas.c:597:67: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                   ~^
#                                                                   %ld
# ./src/blas.c:597:75: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_sim(): sim isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                           ~^
#                                                                           %ld
# ./src/blas.c: In function ‘find_P_constrastive’:
# ./src/blas.c:611:68: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                    ~^
#                                                                    %ld
# ./src/blas.c:611:76: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                            ~^
#                                                                            %ld
# ./src/blas.c:611:84: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          printf(" Error: find_P_constrastive(): P isn't found: i = %d, j = %d, z = %d \n", i, j, z);
#                                                                                    ~^
#                                                                                    %ld
# ./src/blas.c: In function ‘P_constrastive_f’:
# ./src/blas.c:651:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:651:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# ./src/blas.c: In function ‘P_constrastive’:
# ./src/blas.c:785:79: warning: format ‘%d’ expects argument of type ‘int’, but argument 3 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                               ~^
#                                                                               %ld
# ./src/blas.c:785:87: warning: format ‘%d’ expects argument of type ‘int’, but argument 4 has type ‘size_t {aka long unsigned int}’ [-Wformat=]
#          fprintf(stderr, " Error: in P_constrastive must be i != l, while i = %d, l = %d \n", i, l);
#                                                                                       ~^
#                                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/crop_layer.c -o obj/crop_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/dropout_layer.c -o obj/dropout_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/maxpool_layer.c -o obj/maxpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/softmax_layer.c -o obj/softmax_layer.o
# ./src/softmax_layer.c: In function ‘make_contrastive_layer’:
# ./src/softmax_layer.c:203:101: warning: format ‘%d’ expects argument of type ‘int’, but argument 9 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#      fprintf(stderr, "contrastive %4d x%4d x%4d x emb_size %4d x batch: %4d  classes = %4d, step = %4d \n", w, h, l.n, l.embedding_size, batch, l.classes, step);
#                                                                                                    ~~^
#                                                                                                    %4ld
# ./src/softmax_layer.c: In function ‘forward_contrastive_layer’:
# ./src/softmax_layer.c:244:27: warning: variable ‘max_truth’ set but not used [-Wunused-but-set-variable]
#                      float max_truth = 0;
#                            ^~~~~~~~~
# ./src/softmax_layer.c:423:71: warning: format ‘%d’ expects argument of type ‘int’, but argument 2 has type ‘size_t {aka const long unsigned int}’ [-Wformat=]
#              printf(" Error: too large number of bboxes: contr_size = %d > max_contr_size  = %d \n", contr_size, max_contr_size);
#                                                                       ~^
#                                                                       %ld
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/data.c -o obj/data.o
# ./src/data.c: In function ‘load_data_detection’:
# ./src/data.c:1409:43: warning: variable ‘r_scale’ set but not used [-Wunused-but-set-variable]
#      float r1 = 0, r2 = 0, r3 = 0, r4 = 0, r_scale;
#                                            ^~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/matrix.c -o obj/matrix.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/network.c -o obj/network.o
# ./src/network.c: In function ‘train_network_waitkey’:
# ./src/network.c:434:13: warning: unused variable ‘ema_period’ [-Wunused-variable]
#          int ema_period = (net.max_batches - ema_start_point - 1000) * (1.0 - net.ema_alpha);
#              ^~~~~~~~~~
# ./src/network.c: In function ‘resize_network’:
# ./src/network.c:659:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net->input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped))
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/network.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/connected_layer.c -o obj/connected_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/cost_layer.c -o obj/cost_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/parser.c -o obj/parser.o
# ./src/parser.c: In function ‘parse_network_cfg_custom’:
# ./src/parser.c:1689:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess == cudaHostAlloc(&net.input_pinned_cpu, size * sizeof(float), cudaHostRegisterMapped)) net.input_pinned_cpu_flag = 1;
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/activation_layer.h:4,
#                  from ./src/parser.c:6:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/parser.c: In function ‘get_classes_multipliers’:
# ./src/parser.c:431:29: warning: argument 1 range [18446744071562067968, 18446744073709551615] exceeds maximum object size 9223372036854775807 [-Walloc-size-larger-than=]
#          classes_multipliers = (float *)calloc(classes_counters, sizeof(float));
#          ~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# In file included from ./src/parser.c:3:0:
# /usr/include/stdlib.h:541:14: note: in a call to allocation function ‘calloc’ declared here
#  extern void *calloc (size_t __nmemb, size_t __size)
#               ^~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/option_list.c -o obj/option_list.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/darknet.c -o obj/darknet.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/detection_layer.c -o obj/detection_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/captcha.c -o obj/captcha.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/route_layer.c -o obj/route_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/writing.c -o obj/writing.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/box.c -o obj/box.o
# ./src/box.c: In function ‘box_iou_kind’:
# ./src/box.c:154:5: warning: enumeration value ‘MSE’ not handled in switch [-Wswitch]
#      switch(iou_kind) {
#      ^~~~~~
# ./src/box.c: In function ‘diounms_sort’:
# ./src/box.c:898:27: warning: unused variable ‘beta_prob’ [-Wunused-variable]
#                      float beta_prob = pow(dets[j].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~
# ./src/box.c:897:27: warning: unused variable ‘alpha_prob’ [-Wunused-variable]
#                      float alpha_prob = pow(dets[i].prob[k], 2) / sum_prob;
#                            ^~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/nightmare.c -o obj/nightmare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/normalization_layer.c -o obj/normalization_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/avgpool_layer.c -o obj/avgpool_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/coco.c -o obj/coco.o
# ./src/coco.c: In function ‘validate_coco_recall’:
# ./src/coco.c:248:11: warning: unused variable ‘base’ [-Wunused-variable]
#      char *base = "results/comp4_det_test_";
#            ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/dice.c -o obj/dice.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/yolo.c -o obj/yolo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/detector.c -o obj/detector.o
# ./src/detector.c: In function ‘train_detector’:
# ./src/detector.c:386:72: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#              (iteration >= (iter_save + 1000) || iteration % 1000 == 0) && net.max_batches < 10000)
#              ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~~
# ./src/detector.c:319:13: warning: variable ‘draw_precision’ set but not used [-Wunused-but-set-variable]
#          int draw_precision = 0;
#              ^~~~~~~~~~~~~~
# ./src/detector.c:67:11: warning: unused variable ‘avg_contrastive_acc’ [-Wunused-variable]
#      float avg_contrastive_acc = 0;
#            ^~~~~~~~~~~~~~~~~~~
# ./src/detector.c: In function ‘print_cocos’:
# ./src/detector.c:486:29: warning: format not a string literal and no format arguments [-Wformat-security]
#                  fprintf(fp, buff);
#                              ^~~~
# ./src/detector.c: In function ‘eliminate_bdd’:
# ./src/detector.c:579:21: warning: statement with no effect [-Wunused-value]
#                      for (k; buf[k + n] != '\0'; k++)
#                      ^~~
# ./src/detector.c: In function ‘validate_detector’:
# ./src/detector.c:700:13: warning: unused variable ‘mkd2’ [-Wunused-variable]
#          int mkd2 = make_directory(buff2, 0777);
#              ^~~~
# ./src/detector.c:698:13: warning: unused variable ‘mkd’ [-Wunused-variable]
#          int mkd = make_directory(buff, 0777);
#              ^~~
# ./src/detector.c: In function ‘validate_detector_map’:
# ./src/detector.c:1332:15: warning: unused variable ‘class_recall’ [-Wunused-variable]
#          float class_recall = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)(truth_classes_count[i] - tp_for_thresh_per_class[i]));
#                ^~~~~~~~~~~~
# ./src/detector.c:1331:15: warning: unused variable ‘class_precision’ [-Wunused-variable]
#          float class_precision = (float)tp_for_thresh_per_class[i] / ((float)tp_for_thresh_per_class[i] + (float)fp_for_thresh_per_class[i]);
#                ^~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/layer.c -o obj/layer.o
# ./src/layer.c: In function ‘free_layer_custom’:
# ./src/layer.c:208:68: warning: suggest parentheses around ‘&&’ within ‘||’ [-Wparentheses]
#      if (l.delta_gpu && (l.optimized_memory < 1 || l.keep_delta_gpu && l.optimized_memory < 3)) cuda_free(l.delta_gpu), l.delta_gpu = NULL;
#                                                    ~~~~~~~~~~~~~~~~~^~~~~~~~~~~~~~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/compare.c -o obj/compare.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/classifier.c -o obj/classifier.o
# ./src/classifier.c: In function ‘train_classifier’:
# ./src/classifier.c:190:13: warning: variable ‘draw_precision’ set but not used [-Wunused-but-set-variable]
#          int draw_precision = 0;
#              ^~~~~~~~~~~~~~
# ./src/classifier.c:146:9: warning: unused variable ‘count’ [-Wunused-variable]
#      int count = 0;
#          ^~~~~
# ./src/classifier.c:35:11: warning: unused variable ‘avg_contrastive_acc’ [-Wunused-variable]
#      float avg_contrastive_acc = 0;
#            ^~~~~~~~~~~~~~~~~~~
# ./src/classifier.c: In function ‘predict_classifier’:
# ./src/classifier.c:855:13: warning: unused variable ‘time’ [-Wunused-variable]
#      clock_t time;
#              ^~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/local_layer.c -o obj/local_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/swag.c -o obj/swag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/shortcut_layer.c -o obj/shortcut_layer.o
# ./src/shortcut_layer.c: In function ‘make_shortcut_layer’:
# ./src/shortcut_layer.c:55:15: warning: unused variable ‘scale’ [-Wunused-variable]
#          float scale = sqrt(2. / l.nweights);
#                ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/activation_layer.c -o obj/activation_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/rnn_layer.c -o obj/rnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/gru_layer.c -o obj/gru_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/rnn.c -o obj/rnn.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/rnn_vid.c -o obj/rnn_vid.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/crnn_layer.c -o obj/crnn_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/demo.c -o obj/demo.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/tag.c -o obj/tag.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/cifar.c -o obj/cifar.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/go.c -o obj/go.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/batchnorm_layer.c -o obj/batchnorm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/art.c -o obj/art.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/region_layer.c -o obj/region_layer.o
# ./src/region_layer.c: In function ‘resize_region_layer’:
# ./src/region_layer.c:59:9: warning: unused variable ‘old_h’ [-Wunused-variable]
#      int old_h = l->h;
#          ^~~~~
# ./src/region_layer.c:58:9: warning: unused variable ‘old_w’ [-Wunused-variable]
#      int old_w = l->w;
#          ^~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/reorg_layer.c -o obj/reorg_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/reorg_old_layer.c -o obj/reorg_old_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/super.c -o obj/super.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/voxel.c -o obj/voxel.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/tree.c -o obj/tree.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/yolo_layer.c -o obj/yolo_layer.o
# ./src/yolo_layer.c: In function ‘make_yolo_layer’:
# ./src/yolo_layer.c:68:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:75:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs*sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘resize_yolo_layer’:
# ./src/yolo_layer.c:106:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c:115:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/activations.h:3,
#                  from ./src/layer.h:4,
#                  from ./src/yolo_layer.h:5,
#                  from ./src/yolo_layer.c:1:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘process_batch’:
# ./src/yolo_layer.c:426:25: warning: variable ‘best_match_t’ set but not used [-Wunused-but-set-variable]
#                      int best_match_t = 0;
#                          ^~~~~~~~~~~~
# ./src/yolo_layer.c: In function ‘forward_yolo_layer’:
# ./src/yolo_layer.c:707:11: warning: unused variable ‘avg_anyobj’ [-Wunused-variable]
#      float avg_anyobj = 0;
#            ^~~~~~~~~~
# ./src/yolo_layer.c:706:11: warning: unused variable ‘avg_obj’ [-Wunused-variable]
#      float avg_obj = 0;
#            ^~~~~~~
# ./src/yolo_layer.c:705:11: warning: unused variable ‘avg_cat’ [-Wunused-variable]
#      float avg_cat = 0;
#            ^~~~~~~
# ./src/yolo_layer.c:704:11: warning: unused variable ‘recall75’ [-Wunused-variable]
#      float recall75 = 0;
#            ^~~~~~~~
# ./src/yolo_layer.c:703:11: warning: unused variable ‘recall’ [-Wunused-variable]
#      float recall = 0;
#            ^~~~~~
# ./src/yolo_layer.c:702:11: warning: unused variable ‘tot_ciou_loss’ [-Wunused-variable]
#      float tot_ciou_loss = 0;
#            ^~~~~~~~~~~~~
# ./src/yolo_layer.c:701:11: warning: unused variable ‘tot_diou_loss’ [-Wunused-variable]
#      float tot_diou_loss = 0;
#            ^~~~~~~~~~~~~
# ./src/yolo_layer.c:698:11: warning: unused variable ‘tot_ciou’ [-Wunused-variable]
#      float tot_ciou = 0;
#            ^~~~~~~~
# ./src/yolo_layer.c:697:11: warning: unused variable ‘tot_diou’ [-Wunused-variable]
#      float tot_diou = 0;
#            ^~~~~~~~
# ./src/yolo_layer.c:696:11: warning: unused variable ‘tot_giou’ [-Wunused-variable]
#      float tot_giou = 0;
#            ^~~~~~~~
# ./src/yolo_layer.c:668:12: warning: unused variable ‘n’ [-Wunused-variable]
#      int b, n;
#             ^
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/gaussian_yolo_layer.c -o obj/gaussian_yolo_layer.o
# ./src/gaussian_yolo_layer.c: In function ‘make_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:71:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.output, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.output_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:78:38: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#      if (cudaSuccess == cudaHostAlloc(&l.delta, batch*l.outputs * sizeof(float), cudaHostRegisterMapped)) l.delta_pinned = 1;
#                                       ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c: In function ‘resize_gaussian_yolo_layer’:
# ./src/gaussian_yolo_layer.c:110:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->output, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# ./src/gaussian_yolo_layer.c:119:42: warning: passing argument 1 of ‘cudaHostAlloc’ from incompatible pointer type [-Wincompatible-pointer-types]
#          if (cudaSuccess != cudaHostAlloc(&l->delta, l->batch*l->outputs * sizeof(float), cudaHostRegisterMapped)) {
#                                           ^
# In file included from /usr/local/cuda/include/cuda_runtime.h:96:0,
#                  from include/darknet.h:41,
#                  from ./src/gaussian_yolo_layer.h:5,
#                  from ./src/gaussian_yolo_layer.c:7:
# /usr/local/cuda/include/cuda_runtime_api.h:4707:39: note: expected ‘void **’ but argument is of type ‘float **’
#  extern __host__ cudaError_t CUDARTAPI cudaHostAlloc(void **pHost, size_t size, unsigned int flags);
#                                        ^~~~~~~~~~~~~
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/upsample_layer.c -o obj/upsample_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/lstm_layer.c -o obj/lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/conv_lstm_layer.c -o obj/conv_lstm_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/scale_channels_layer.c -o obj/scale_channels_layer.o
# gcc -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU -c ./src/sam_layer.c -o obj/sam_layer.o
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU" -c ./src/convolutional_kernels.cu -o obj/convolutional_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU" -c ./src/activation_kernels.cu -o obj/activation_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# ./src/activation_kernels.cu(263): warning: variable "MISH_THRESHOLD" was declared but never referenced
#
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU" -c ./src/im2col_kernels.cu -o obj/im2col_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU" -c ./src/col2im_kernels.cu -o obj/col2im_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU" -c ./src/blas_kernels.cu -o obj/blas_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu(1086): warning: variable "out_index" was declared but never referenced
#
# ./src/blas_kernels.cu(1130): warning: variable "step" was set but never used
#
# ./src/blas_kernels.cu(1736): warning: variable "stage_id" was declared but never referenced
#
# ./src/blas_kernels.cu: In function ‘void backward_shortcut_multilayer_gpu(int, int, int, int*, float**, float*, float*, float*, float*, int, float*, float**, WEIGHTS_NORMALIZATION_T)’:
# ./src/blas_kernels.cu:1130:5: warning: variable ‘step’ set but not used [-Wunused-but-set-variable]
#      int step = 0;
#      ^~~~
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU" -c ./src/crop_layer_kernels.cu -o obj/crop_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU" -c ./src/dropout_layer_kernels.cu -o obj/dropout_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU" -c ./src/maxpool_layer_kernels.cu -o obj/maxpool_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU" -c ./src/network_kernels.cu -o obj/network_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu(364): warning: variable "l" was declared but never referenced
#
# ./src/network_kernels.cu: In function ‘float train_network_datum_gpu(network, float*, float*)’:
# ./src/network_kernels.cu:364:7: warning: variable ‘l’ set but not used [-Wunused-but-set-variable]
#          layer l = net.layers[net.n - 1];
#        ^
# nvcc -gencode arch=compute_35,code=sm_35 -gencode arch=compute_50,code=[sm_50,compute_50] -gencode arch=compute_52,code=[sm_52,compute_52] -gencode arch=compute_61,code=[sm_61,compute_61] -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ --compiler-options "-Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU" -c ./src/avgpool_layer_kernels.cu -o obj/avgpool_layer_kernels.o
# nvcc warning : The 'compute_35', 'compute_37', 'compute_50', 'sm_35', 'sm_37' and 'sm_50' architectures are deprecated, and may be removed in a future release (Use -Wno-deprecated-gpu-targets to suppress warning).
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DGPU -I/usr/local/cuda/include/ -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DGPU obj/image_opencv.o obj/http_stream.o obj/gemm.o obj/utils.o obj/dark_cuda.o obj/convolutional_layer.o obj/list.o obj/image.o obj/activations.o obj/im2col.o obj/col2im.o obj/blas.o obj/crop_layer.o obj/dropout_layer.o obj/maxpool_layer.o obj/softmax_layer.o obj/data.o obj/matrix.o obj/network.o obj/connected_layer.o obj/cost_layer.o obj/parser.o obj/option_list.o obj/darknet.o obj/detection_layer.o obj/captcha.o obj/route_layer.o obj/writing.o obj/box.o obj/nightmare.o obj/normalization_layer.o obj/avgpool_layer.o obj/coco.o obj/dice.o obj/yolo.o obj/detector.o obj/layer.o obj/compare.o obj/classifier.o obj/local_layer.o obj/swag.o obj/shortcut_layer.o obj/activation_layer.o obj/rnn_layer.o obj/gru_layer.o obj/rnn.o obj/rnn_vid.o obj/crnn_layer.o obj/demo.o obj/tag.o obj/cifar.o obj/go.o obj/batchnorm_layer.o obj/art.o obj/region_layer.o obj/reorg_layer.o obj/reorg_old_layer.o obj/super.o obj/voxel.o obj/tree.o obj/yolo_layer.o obj/gaussian_yolo_layer.o obj/upsample_layer.o obj/lstm_layer.o obj/conv_lstm_layer.o obj/scale_channels_layer.o obj/sam_layer.o obj/convolutional_kernels.o obj/activation_kernels.o obj/im2col_kernels.o obj/col2im_kernels.o obj/blas_kernels.o obj/crop_layer_kernels.o obj/dropout_layer_kernels.o obj/maxpool_layer_kernels.o obj/network_kernels.o obj/avgpool_layer_kernels.o -o darknet -lm -pthread -L/usr/local/cuda/lib64 -lcuda -lcudart -lcublas -lcurand -lstdc++

# %%
# downloading YOLO model
os.chdir("/content/darknet")
# !wget https://www.dropbox.com/s/m3tg61e1wsvawoq/darknet53.conv.74
# Out:
# --2021-03-22 05:22:53--  https://www.dropbox.com/s/m3tg61e1wsvawoq/darknet53.conv.74
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.6.18, 2620:100:6019:18::a27d:412
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.6.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/m3tg61e1wsvawoq/darknet53.conv.74 [following]
# --2021-03-22 05:22:53--  https://www.dropbox.com/s/raw/m3tg61e1wsvawoq/darknet53.conv.74
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uce643964e0d97ac38514889c3e3.dl.dropboxusercontent.com/cd/0/inline/BLLZ7xdQHLdOWyITY8RmdLCEwkifReKslmVzkcVxzg_OWxVTwSO2usM5LzbJHdZjzVYAkjFO4owp3qPA7CdFq_Bl3YuANszN1AUpD-iS_3M_X2eM7f96C7LDbiS2bNIUhYM0W3uGxdP06eMZLRIbzR0Z/file# [following]
# --2021-03-22 05:22:54--  https://uce643964e0d97ac38514889c3e3.dl.dropboxusercontent.com/cd/0/inline/BLLZ7xdQHLdOWyITY8RmdLCEwkifReKslmVzkcVxzg_OWxVTwSO2usM5LzbJHdZjzVYAkjFO4owp3qPA7CdFq_Bl3YuANszN1AUpD-iS_3M_X2eM7f96C7LDbiS2bNIUhYM0W3uGxdP06eMZLRIbzR0Z/file
# Resolving uce643964e0d97ac38514889c3e3.dl.dropboxusercontent.com (uce643964e0d97ac38514889c3e3.dl.dropboxusercontent.com)... 162.125.7.15, 2620:100:6019:15::a27d:40f
# Connecting to uce643964e0d97ac38514889c3e3.dl.dropboxusercontent.com (uce643964e0d97ac38514889c3e3.dl.dropboxusercontent.com)|162.125.7.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/BLJ69h8HA17aSaE4FqF5wVLTXYsdAwQxp8qlriD_HudJ7GukQ2gvVPtTAZ8jDOSll07Wly8PA_0f61FjLbENJQk8Htg5xZfPdihtmnNnBNHHpfSccDXtDnYqvloVvcPM2CPfpwr3RPyzwYOpThWJwfKKsLL824rBAfyWh5JsjDDosHSDPxhPRHCwjn46J1IZ08yxghnwBGopTTFdV5HMgapGO35VD-0wZyIIODcezCd0u5PS7h3lRlqt6Q1y7Lo9UDOAJlJItis5BaucpMcT6mcsOGnQpfdMigeqZI0KGMphjrI7A2c_rQlsHhCN_AZhetB0NmGWK3rLj9g20voaiL2Ivco3Ya0dmx0FsnFMf9UJF6veS8KNPONSv8uR7K_THeA/file [following]
# --2021-03-22 05:22:56--  https://uce643964e0d97ac38514889c3e3.dl.dropboxusercontent.com/cd/0/inline2/BLJ69h8HA17aSaE4FqF5wVLTXYsdAwQxp8qlriD_HudJ7GukQ2gvVPtTAZ8jDOSll07Wly8PA_0f61FjLbENJQk8Htg5xZfPdihtmnNnBNHHpfSccDXtDnYqvloVvcPM2CPfpwr3RPyzwYOpThWJwfKKsLL824rBAfyWh5JsjDDosHSDPxhPRHCwjn46J1IZ08yxghnwBGopTTFdV5HMgapGO35VD-0wZyIIODcezCd0u5PS7h3lRlqt6Q1y7Lo9UDOAJlJItis5BaucpMcT6mcsOGnQpfdMigeqZI0KGMphjrI7A2c_rQlsHhCN_AZhetB0NmGWK3rLj9g20voaiL2Ivco3Ya0dmx0FsnFMf9UJF6veS8KNPONSv8uR7K_THeA/file
# Reusing existing connection to uce643964e0d97ac38514889c3e3.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  39.5MB/s    in 4.2s
#
# 2021-03-22 05:23:01 (36.6 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# ## Gettting dataset

# %%
os.chdir("/content/darknet/data")
# !wget -q https://www.dropbox.com/s/v2gmvmup24m5kzq/yolo-dataset.zip

# %%
# !unzip yolo-dataset.zip
# Out:
# Archive:  yolo-dataset.zip
#   inflating: obj.data
#    creating: __MACOSX/
#   inflating: __MACOSX/._obj.data
#   inflating: train.txt
#    creating: img/
#   inflating: img/output-000000034.txt
#   inflating: img/output-000000308.jpg
#   inflating: img/output-000000746.txt
#   inflating: img/output-000000020.txt
#   inflating: img/output-000000334.jpg
#   inflating: img/output-000000008.txt
#   inflating: img/output-000000452.jpg
#   inflating: img/output-000000446.jpg
#   inflating: img/output-000000320.jpg
#   inflating: img/output-000000491.jpg
#   inflating: img/output-000000485.jpg
#   inflating: img/output-000000550.txt
#   inflating: img/output-000000236.txt
#   inflating: img/output-000000222.txt
#   inflating: img/output-000000678.jpg
#   inflating: img/output-000000544.txt
#   inflating: img/output-000000650.jpg
#   inflating: img/output-000000136.jpg
#   inflating: img/output-000000122.jpg
#   inflating: img/output-000000578.txt
#   inflating: img/output-000000644.jpg
#   inflating: img/output-000000593.txt
#   inflating: img/output-000000587.txt
#   inflating: img/output-000000693.jpg
#   inflating: img/output-000000687.jpg
#   inflating: img/output-000000424.txt
#   inflating: img/output-000000718.jpg
#   inflating: img/output-000000342.txt
#   inflating: img/output-000000356.txt
#   inflating: img/output-000000430.txt
#   inflating: img/output-000000724.jpg
#   inflating: img/output-000000418.txt
#   inflating: img/output-000000042.jpg
#   inflating: img/output-000000056.jpg
#   inflating: img/output-000000730.jpg
#   inflating: img/output-000000381.txt
#   inflating: img/output-000000395.txt
#   inflating: img/output-000000081.jpg
#   inflating: img/output-000000095.jpg
#   inflating: img/output-000000140.txt
#   inflating: img/output-000000626.txt
#   inflating: img/output-000000632.txt
#   inflating: img/output-000000268.jpg
#   inflating: img/output-000000154.txt
#   inflating: img/output-000000240.jpg
#   inflating: img/output-000000526.jpg
#   inflating: img/output-000000532.jpg
#   inflating: img/output-000000168.txt
#   inflating: img/output-000000254.jpg
#   inflating: img/output-000000183.txt
#   inflating: img/output-000000197.txt
#   inflating: img/output-000000283.jpg
#   inflating: img/output-000000297.jpg
#   inflating: img/output-000000296.jpg
#   inflating: img/output-000000282.jpg
#   inflating: img/output-000000196.txt
#   inflating: img/output-000000182.txt
#   inflating: img/output-000000533.jpg
#   inflating: img/output-000000255.jpg
#   inflating: img/output-000000169.txt
#   inflating: img/output-000000241.jpg
#   inflating: img/output-000000527.jpg
#   inflating: img/output-000000633.txt
#   inflating: img/output-000000155.txt
#   inflating: img/output-000000269.jpg
#   inflating: img/output-000000141.txt
#   inflating: img/output-000000627.txt
#   inflating: img/output-000000094.jpg
#   inflating: img/output-000000080.jpg
#   inflating: img/output-000000394.txt
#   inflating: img/output-000000380.txt
#   inflating: img/output-000000057.jpg
#   inflating: img/output-000000731.jpg
#   inflating: img/output-000000419.txt
#   inflating: img/output-000000725.jpg
#   inflating: img/output-000000043.jpg
#   inflating: img/output-000000357.txt
#   inflating: img/output-000000431.txt
#   inflating: img/output-000000719.jpg
#   inflating: img/output-000000425.txt
#   inflating: img/output-000000343.txt
#   inflating: img/output-000000686.jpg
#   inflating: img/output-000000692.jpg
#   inflating: img/output-000000586.txt
#   inflating: img/output-000000592.txt
#   inflating: img/output-000000123.jpg
#   inflating: img/output-000000645.jpg
#   inflating: img/output-000000579.txt
#   inflating: img/output-000000651.jpg
#   inflating: img/output-000000137.jpg
#   inflating: img/output-000000223.txt
#   inflating: img/output-000000545.txt
#   inflating: img/output-000000679.jpg
#   inflating: img/output-000000551.txt
#   inflating: img/output-000000237.txt
#   inflating: img/output-000000484.jpg
#   inflating: img/output-000000490.jpg
#   inflating: img/output-000000447.jpg
#   inflating: img/output-000000321.jpg
#   inflating: img/output-000000009.txt
#   inflating: img/output-000000335.jpg
#   inflating: img/output-000000453.jpg
#   inflating: img/output-000000747.txt
#   inflating: img/output-000000021.txt
#   inflating: img/output-000000309.jpg
#   inflating: img/output-000000035.txt
#   inflating: img/output-000000023.txt
#   inflating: img/output-000000745.txt
#   inflating: img/output-000000479.jpg
#   inflating: img/output-000000037.txt
#   inflating: img/output-000000323.jpg
#   inflating: img/output-000000445.jpg
#   inflating: img/output-000000451.jpg
#   inflating: img/output-000000337.jpg
#   inflating: img/output-000000486.jpg
#   inflating: img/output-000000492.jpg
#   inflating: img/output-000000547.txt
#   inflating: img/output-000000221.txt
#   inflating: img/output-000000109.jpg
#   inflating: img/output-000000235.txt
#   inflating: img/output-000000553.txt
#   inflating: img/output-000000647.jpg
#   inflating: img/output-000000121.jpg
#   inflating: img/output-000000209.txt
#   inflating: img/output-000000135.jpg
#   inflating: img/output-000000653.jpg
#   inflating: img/output-000000584.txt
#   inflating: img/output-000000590.txt
#   inflating: img/output-000000684.jpg
#   inflating: img/output-000000690.jpg
#   inflating: img/output-000000433.txt
#   inflating: img/output-000000355.txt
#   inflating: img/output-000000069.jpg
#   inflating: img/output-000000341.txt
#   inflating: img/output-000000427.txt
#   inflating: img/output-000000733.jpg
#   inflating: img/output-000000055.jpg
#   inflating: img/output-000000369.txt
#   inflating: img/output-000000041.jpg
#   inflating: img/output-000000727.jpg
#   inflating: img/output-000000396.txt
#   inflating: img/output-000000382.txt
#   inflating: img/output-000000096.jpg
#   inflating: img/output-000000082.jpg
#   inflating: img/output-000000157.txt
#   inflating: img/output-000000631.txt
#   inflating: img/output-000000519.jpg
#   inflating: img/output-000000625.txt
#   inflating: img/output-000000143.txt
#   inflating: img/output-000000257.jpg
#   inflating: img/output-000000531.jpg
#   inflating: img/output-000000619.txt
#   inflating: img/output-000000525.jpg
#   inflating: img/output-000000243.jpg
#   inflating: img/output-000000194.txt
#   inflating: img/output-000000180.txt
#   inflating: img/output-000000294.jpg
#   inflating: img/output-000000280.jpg
#   inflating: img/output-000000281.jpg
#   inflating: img/output-000000295.jpg
#   inflating: img/output-000000181.txt
#   inflating: img/output-000000195.txt
#   inflating: img/output-000000524.jpg
#   inflating: img/output-000000618.txt
#   inflating: img/output-000000242.jpg
#   inflating: img/output-000000256.jpg
#   inflating: img/output-000000530.jpg
#   inflating: img/output-000000624.txt
#   inflating: img/output-000000518.jpg
#   inflating: img/output-000000142.txt
#   inflating: img/output-000000156.txt
#   inflating: img/output-000000630.txt
#   inflating: img/output-000000083.jpg
#   inflating: img/output-000000097.jpg
#   inflating: img/output-000000383.txt
#   inflating: img/output-000000397.txt
#   inflating: img/output-000000040.jpg
#   inflating: img/output-000000726.jpg
#   inflating: img/output-000000732.jpg
#   inflating: img/output-000000368.txt
#   inflating: img/output-000000054.jpg
#   inflating: img/output-000000340.txt
#   inflating: img/output-000000426.txt
#   inflating: img/output-000000432.txt
#   inflating: img/output-000000068.jpg
#   inflating: img/output-000000354.txt
#   inflating: img/output-000000691.jpg
#   inflating: img/output-000000685.jpg
#   inflating: img/output-000000591.txt
#   inflating: img/output-000000585.txt
#   inflating: img/output-000000134.jpg
#   inflating: img/output-000000208.txt
#   inflating: img/output-000000652.jpg
#   inflating: img/output-000000646.jpg
#   inflating: img/output-000000120.jpg
#   inflating: img/output-000000234.txt
#   inflating: img/output-000000108.jpg
#   inflating: img/output-000000552.txt
#   inflating: img/output-000000546.txt
#   inflating: img/output-000000220.txt
#   inflating: img/output-000000493.jpg
#   inflating: img/output-000000487.jpg
#   inflating: img/output-000000450.jpg
#   inflating: img/output-000000336.jpg
#   inflating: img/output-000000322.jpg
#   inflating: img/output-000000444.jpg
#   inflating: img/output-000000750.txt
#   inflating: img/output-000000036.txt
#   inflating: img/output-000000022.txt
#   inflating: img/output-000000478.jpg
#   inflating: img/output-000000744.txt
#   inflating: img/output-000000440.jpg
#   inflating: img/output-000000326.jpg
#   inflating: img/output-000000332.jpg
#   inflating: img/output-000000454.jpg
#   inflating: img/output-000000740.txt
#   inflating: img/output-000000026.txt
#   inflating: img/output-000000032.txt
#   inflating: img/output-000000468.jpg
#   inflating: img/output-000000483.jpg
#   inflating: img/output-000000497.jpg
#   inflating: img/output-000000124.jpg
#   inflating: img/output-000000218.txt
#   inflating: img/output-000000642.jpg
#   inflating: img/output-000000656.jpg
#   inflating: img/output-000000130.jpg
#   inflating: img/output-000000224.txt
#   inflating: img/output-000000118.jpg
#   inflating: img/output-000000542.txt
#   inflating: img/output-000000556.txt
#   inflating: img/output-000000230.txt
#   inflating: img/output-000000681.jpg
#   inflating: img/output-000000695.jpg
#   inflating: img/output-000000581.txt
#   inflating: img/output-000000595.txt
#   inflating: img/output-000000050.jpg
#   inflating: img/output-000000736.jpg
#   inflating: img/output-000000722.jpg
#   inflating: img/output-000000378.txt
#   inflating: img/output-000000044.jpg
#   inflating: img/output-000000350.txt
#   inflating: img/output-000000436.txt
#   inflating: img/output-000000422.txt
#   inflating: img/output-000000078.jpg
#   inflating: img/output-000000344.txt
#   inflating: img/output-000000093.jpg
#   inflating: img/output-000000087.jpg
#   inflating: img/output-000000393.txt
#   inflating: img/output-000000387.txt
#   inflating: img/output-000000534.jpg
#   inflating: img/output-000000608.txt
#   inflating: img/output-000000252.jpg
#   inflating: img/output-000000246.jpg
#   inflating: img/output-000000520.jpg
#   inflating: img/output-000000634.txt
#   inflating: img/output-000000508.jpg
#   inflating: img/output-000000152.txt
#   inflating: img/output-000000146.txt
#   inflating: img/output-000000620.txt
#   inflating: img/output-000000291.jpg
#   inflating: img/output-000000285.jpg
#   inflating: img/output-000000191.txt
#   inflating: img/output-000000185.txt
#   inflating: img/output-000000184.txt
#   inflating: img/output-000000190.txt
#   inflating: img/output-000000284.jpg
#   inflating: img/output-000000290.jpg
#   inflating: img/output-000000147.txt
#   inflating: img/output-000000621.txt
#   inflating: img/output-000000509.jpg
#   inflating: img/output-000000635.txt
#   inflating: img/output-000000153.txt
#   inflating: img/output-000000247.jpg
#   inflating: img/output-000000521.jpg
#   inflating: img/output-000000609.txt
#   inflating: img/output-000000535.jpg
#   inflating: img/output-000000253.jpg
#   inflating: img/output-000000386.txt
#   inflating: img/output-000000392.txt
#   inflating: img/output-000000086.jpg
#   inflating: img/output-000000092.jpg
#   inflating: img/output-000000423.txt
#   inflating: img/output-000000345.txt
#   inflating: img/output-000000079.jpg
#   inflating: img/output-000000351.txt
#   inflating: img/output-000000437.txt
#   inflating: img/output-000000723.jpg
#   inflating: img/output-000000045.jpg
#   inflating: img/output-000000379.txt
#   inflating: img/output-000000051.jpg
#   inflating: img/output-000000737.jpg
#   inflating: img/output-000000594.txt
#   inflating: img/output-000000580.txt
#   inflating: img/output-000000694.jpg
#   inflating: img/output-000000680.jpg
#   inflating: img/output-000000557.txt
#   inflating: img/output-000000231.txt
#   inflating: img/output-000000119.jpg
#   inflating: img/output-000000225.txt
#   inflating: img/output-000000543.txt
#   inflating: img/output-000000657.jpg
#   inflating: img/output-000000131.jpg
#   inflating: img/output-000000219.txt
#   inflating: img/output-000000125.jpg
#   inflating: img/output-000000643.jpg
#   inflating: img/output-000000496.jpg
#   inflating: img/output-000000482.jpg
#   inflating: img/output-000000033.txt
#   inflating: img/output-000000469.jpg
#   inflating: img/output-000000741.txt
#   inflating: img/output-000000027.txt
#   inflating: img/output-000000333.jpg
#   inflating: img/output-000000455.jpg
#   inflating: img/output-000000441.jpg
#   inflating: img/output-000000327.jpg
#   inflating: img/output-000000457.jpg
#   inflating: img/output-000000331.jpg
#   inflating: img/output-000000019.txt
#   inflating: img/output-000000325.jpg
#   inflating: img/output-000000443.jpg
#   inflating: img/output-000000031.txt
#   inflating: img/output-000000319.jpg
#   inflating: img/output-000000025.txt
#   inflating: img/output-000000743.txt
#   inflating: img/output-000000494.jpg
#   inflating: img/output-000000480.jpg
#   inflating: img/output-000000133.jpg
#   inflating: img/output-000000655.jpg
#   inflating: img/output-000000569.txt
#   inflating: img/output-000000641.jpg
#   inflating: img/output-000000127.jpg
#   inflating: img/output-000000233.txt
#   inflating: img/output-000000555.txt
#   inflating: img/output-000000669.jpg
#   inflating: img/output-000000541.txt
#   inflating: img/output-000000227.txt
#   inflating: img/output-000000696.jpg
#   inflating: img/output-000000682.jpg
#   inflating: img/output-000000596.txt
#   inflating: img/output-000000582.txt
#   inflating: img/output-000000047.jpg
#   inflating: img/output-000000721.jpg
#   inflating: img/output-000000409.txt
#   inflating: img/output-000000735.jpg
#   inflating: img/output-000000053.jpg
#   inflating: img/output-000000347.txt
#   inflating: img/output-000000421.txt
#   inflating: img/output-000000709.jpg
#   inflating: img/output-000000435.txt
#   inflating: img/output-000000353.txt
#   inflating: img/output-000000084.jpg
#   inflating: img/output-000000090.jpg
#   inflating: img/output-000000384.txt
#   inflating: img/output-000000390.txt
#   inflating: img/output-000000523.jpg
#   inflating: img/output-000000245.jpg
#   inflating: img/output-000000179.txt
#   inflating: img/output-000000251.jpg
#   inflating: img/output-000000537.jpg
#   inflating: img/output-000000623.txt
#   inflating: img/output-000000145.txt
#   inflating: img/output-000000279.jpg
#   inflating: img/output-000000151.txt
#   inflating: img/output-000000637.txt
#   inflating: img/output-000000286.jpg
#   inflating: img/output-000000292.jpg
#   inflating: img/output-000000186.txt
#   inflating: img/output-000000192.txt
#   inflating: img/output-000000193.txt
#   inflating: img/output-000000187.txt
#   inflating: img/output-000000293.jpg
#   inflating: img/output-000000287.jpg
#   inflating: img/output-000000150.txt
#   inflating: img/output-000000636.txt
#   inflating: img/output-000000622.txt
#   inflating: img/output-000000278.jpg
#   inflating: img/output-000000144.txt
#   inflating: img/output-000000250.jpg
#   inflating: img/output-000000536.jpg
#   inflating: img/output-000000522.jpg
#   inflating: img/output-000000178.txt
#   inflating: img/output-000000244.jpg
#   inflating: img/output-000000391.txt
#   inflating: img/output-000000385.txt
#   inflating: img/output-000000091.jpg
#   inflating: img/output-000000085.jpg
#   inflating: img/output-000000434.txt
#   inflating: img/output-000000708.jpg
#   inflating: img/output-000000352.txt
#   inflating: img/output-000000346.txt
#   inflating: img/output-000000420.txt
#   inflating: img/output-000000734.jpg
#   inflating: img/output-000000408.txt
#   inflating: img/output-000000052.jpg
#   inflating: img/output-000000046.jpg
#   inflating: img/output-000000720.jpg
#   inflating: img/output-000000583.txt
#   inflating: img/output-000000597.txt
#   inflating: img/output-000000683.jpg
#   inflating: img/output-000000697.jpg
#   inflating: img/output-000000540.txt
#   inflating: img/output-000000226.txt
#   inflating: img/output-000000232.txt
#   inflating: img/output-000000668.jpg
#   inflating: img/output-000000554.txt
#   inflating: img/output-000000640.jpg
#   inflating: img/output-000000126.jpg
#   inflating: img/output-000000132.jpg
#   inflating: img/output-000000568.txt
#   inflating: img/output-000000654.jpg
#   inflating: img/output-000000481.jpg
#   inflating: img/output-000000495.jpg
#   inflating: img/output-000000024.txt
#   inflating: img/output-000000318.jpg
#   inflating: img/output-000000742.txt
#   inflating: img/output-000000030.txt
#   inflating: img/output-000000324.jpg
#   inflating: img/output-000000018.txt
#   inflating: img/output-000000442.jpg
#   inflating: img/output-000000456.jpg
#   inflating: img/output-000000330.jpg
#   inflating: img/output-000000731.txt
#   inflating: img/output-000000057.txt
#   inflating: img/output-000000043.txt
#   inflating: img/output-000000419.jpg
#   inflating: img/output-000000725.txt
#   inflating: img/output-000000431.jpg
#   inflating: img/output-000000357.jpg
#   inflating: img/output-000000343.jpg
#   inflating: img/output-000000719.txt
#   inflating: img/output-000000425.jpg
#   inflating: img/output-000000094.txt
#   inflating: img/output-000000080.txt
#   inflating: img/output-000000394.jpg
#   inflating: img/output-000000380.jpg
#   inflating: img/output-000000255.txt
#   inflating: img/output-000000169.jpg
#   inflating: img/output-000000533.txt
#   inflating: img/output-000000527.txt
#   inflating: img/output-000000241.txt
#   inflating: img/output-000000155.jpg
#   inflating: img/output-000000269.txt
#   inflating: img/output-000000633.jpg
#   inflating: img/output-000000627.jpg
#   inflating: img/output-000000141.jpg
#   inflating: img/output-000000296.txt
#   inflating: img/output-000000282.txt
#   inflating: img/output-000000196.jpg
#   inflating: img/output-000000182.jpg
#   inflating: img/output-000000321.txt
#   inflating: img/output-000000447.txt
#   inflating: img/output-000000453.txt
#   inflating: img/output-000000009.jpg
#   inflating: img/output-000000335.txt
#   inflating: img/output-000000021.jpg
#   inflating: img/output-000000747.jpg
#   inflating: img/output-000000309.txt
#   inflating: img/output-000000035.jpg
#   inflating: img/output-000000484.txt
#   inflating: img/output-000000490.txt
#   inflating: img/output-000000645.txt
#   inflating: img/output-000000579.jpg
#   inflating: img/output-000000123.txt
#   inflating: img/output-000000137.txt
#   inflating: img/output-000000651.txt
#   inflating: img/output-000000545.jpg
#   inflating: img/output-000000679.txt
#   inflating: img/output-000000223.jpg
#   inflating: img/output-000000237.jpg
#   inflating: img/output-000000551.jpg
#   inflating: img/output-000000686.txt
#   inflating: img/output-000000692.txt
#   inflating: img/output-000000586.jpg
#   inflating: img/output-000000592.jpg
#   inflating: img/output-000000593.jpg
#   inflating: img/output-000000587.jpg
#   inflating: img/output-000000693.txt
#   inflating: img/output-000000687.txt
#   inflating: img/output-000000236.jpg
#   inflating: img/output-000000550.jpg
#   inflating: img/output-000000678.txt
#   inflating: img/output-000000544.jpg
#   inflating: img/output-000000222.jpg
#   inflating: img/output-000000136.txt
#   inflating: img/output-000000650.txt
#   inflating: img/output-000000578.jpg
#   inflating: img/output-000000644.txt
#   inflating: img/output-000000122.txt
#   inflating: img/output-000000491.txt
#   inflating: img/output-000000485.txt
#   inflating: img/output-000000034.jpg
#   inflating: img/output-000000308.txt
#   inflating: img/output-000000020.jpg
#   inflating: img/output-000000746.jpg
#   inflating: img/output-000000452.txt
#   inflating: img/output-000000334.txt
#   inflating: img/output-000000008.jpg
#   inflating: img/output-000000320.txt
#   inflating: img/output-000000446.txt
#   inflating: img/output-000000183.jpg
#   inflating: img/output-000000197.jpg
#   inflating: img/output-000000283.txt
#   inflating: img/output-000000297.txt
#   inflating: img/output-000000626.jpg
#   inflating: img/output-000000140.jpg
#   inflating: img/output-000000268.txt
#   inflating: img/output-000000154.jpg
#   inflating: img/output-000000632.jpg
#   inflating: img/output-000000526.txt
#   inflating: img/output-000000240.txt
#   inflating: img/output-000000168.jpg
#   inflating: img/output-000000254.txt
#   inflating: img/output-000000532.txt
#   inflating: img/output-000000381.jpg
#   inflating: img/output-000000395.jpg
#   inflating: img/output-000000081.txt
#   inflating: img/output-000000095.txt
#   inflating: img/output-000000342.jpg
#   inflating: img/output-000000424.jpg
#   inflating: img/output-000000718.txt
#   inflating: img/output-000000430.jpg
#   inflating: img/output-000000356.jpg
#   inflating: img/output-000000042.txt
#   inflating: img/output-000000724.txt
#   inflating: img/output-000000418.jpg
#   inflating: img/output-000000730.txt
#   inflating: img/output-000000056.txt
#   inflating: img/output-000000726.txt
#   inflating: img/output-000000040.txt
#   inflating: img/output-000000368.jpg
#   inflating: img/output-000000054.txt
#   inflating: img/output-000000732.txt
#   inflating: img/output-000000426.jpg
#   inflating: img/output-000000340.jpg
#   inflating: img/output-000000068.txt
#   inflating: img/output-000000354.jpg
#   inflating: img/output-000000432.jpg
#   inflating: img/output-000000083.txt
#   inflating: img/output-000000097.txt
#   inflating: img/output-000000383.jpg
#   inflating: img/output-000000397.jpg
#   inflating: img/output-000000242.txt
#   inflating: img/output-000000524.txt
#   inflating: img/output-000000618.jpg
#   inflating: img/output-000000530.txt
#   inflating: img/output-000000256.txt
#   inflating: img/output-000000142.jpg
#   inflating: img/output-000000624.jpg
#   inflating: img/output-000000518.txt
#   inflating: img/output-000000630.jpg
#   inflating: img/output-000000156.jpg
#   inflating: img/output-000000281.txt
#   inflating: img/output-000000295.txt
#   inflating: img/output-000000181.jpg
#   inflating: img/output-000000195.jpg
#   inflating: img/output-000000336.txt
#   inflating: img/output-000000450.txt
#   inflating: img/output-000000444.txt
#   inflating: img/output-000000322.txt
#   inflating: img/output-000000036.jpg
#   inflating: img/output-000000750.jpg
#   inflating: img/output-000000478.txt
#   inflating: img/output-000000744.jpg
#   inflating: img/output-000000022.jpg
#   inflating: img/output-000000493.txt
#   inflating: img/output-000000487.txt
#   inflating: img/output-000000652.txt
#   inflating: img/output-000000134.txt
#   inflating: img/output-000000208.jpg
#   inflating: img/output-000000120.txt
#   inflating: img/output-000000646.txt
#   inflating: img/output-000000552.jpg
#   inflating: img/output-000000234.jpg
#   inflating: img/output-000000108.txt
#   inflating: img/output-000000220.jpg
#   inflating: img/output-000000546.jpg
#   inflating: img/output-000000691.txt
#   inflating: img/output-000000685.txt
#   inflating: img/output-000000591.jpg
#   inflating: img/output-000000585.jpg
#   inflating: img/output-000000584.jpg
#   inflating: img/output-000000590.jpg
#   inflating: img/output-000000684.txt
#   inflating: img/output-000000690.txt
#   inflating: img/output-000000221.jpg
#   inflating: img/output-000000547.jpg
#   inflating: img/output-000000553.jpg
#   inflating: img/output-000000109.txt
#   inflating: img/output-000000235.jpg
#   inflating: img/output-000000121.txt
#   inflating: img/output-000000647.txt
#   inflating: img/output-000000653.txt
#   inflating: img/output-000000209.jpg
#   inflating: img/output-000000135.txt
#   inflating: img/output-000000486.txt
#   inflating: img/output-000000492.txt
#   inflating: img/output-000000745.jpg
#   inflating: img/output-000000479.txt
#   inflating: img/output-000000023.jpg
#   inflating: img/output-000000037.jpg
#   inflating: img/output-000000445.txt
#   inflating: img/output-000000323.txt
#   inflating: img/output-000000337.txt
#   inflating: img/output-000000451.txt
#   inflating: img/output-000000194.jpg
#   inflating: img/output-000000180.jpg
#   inflating: img/output-000000294.txt
#   inflating: img/output-000000280.txt
#   inflating: img/output-000000631.jpg
#   inflating: img/output-000000157.jpg
#   inflating: img/output-000000143.jpg
#   inflating: img/output-000000519.txt
#   inflating: img/output-000000625.jpg
#   inflating: img/output-000000531.txt
#   inflating: img/output-000000257.txt
#   inflating: img/output-000000243.txt
#   inflating: img/output-000000619.jpg
#   inflating: img/output-000000525.txt
#   inflating: img/output-000000396.jpg
#   inflating: img/output-000000382.jpg
#   inflating: img/output-000000096.txt
#   inflating: img/output-000000082.txt
#   inflating: img/output-000000355.jpg
#   inflating: img/output-000000069.txt
#   inflating: img/output-000000433.jpg
#   inflating: img/output-000000427.jpg
#   inflating: img/output-000000341.jpg
#   inflating: img/output-000000055.txt
#   inflating: img/output-000000369.jpg
#   inflating: img/output-000000733.txt
#   inflating: img/output-000000727.txt
#   inflating: img/output-000000041.txt
#   inflating: img/output-000000345.jpg
#   inflating: img/output-000000079.txt
#   inflating: img/output-000000423.jpg
#   inflating: img/output-000000437.jpg
#   inflating: img/output-000000351.jpg
#   inflating: img/output-000000045.txt
#   inflating: img/output-000000379.jpg
#   inflating: img/output-000000723.txt
#   inflating: img/output-000000737.txt
#   inflating: img/output-000000051.txt
#   inflating: img/output-000000386.jpg
#   inflating: img/output-000000392.jpg
#   inflating: img/output-000000086.txt
#   inflating: img/output-000000092.txt
#   inflating: img/output-000000621.jpg
#   inflating: img/output-000000147.jpg
#   inflating: img/output-000000153.jpg
#   inflating: img/output-000000509.txt
#   inflating: img/output-000000635.jpg
#   inflating: img/output-000000521.txt
#   inflating: img/output-000000247.txt
#   inflating: img/output-000000253.txt
#   inflating: img/output-000000609.jpg
#   inflating: img/output-000000535.txt
#   inflating: img/output-000000184.jpg
#   inflating: img/output-000000190.jpg
#   inflating: img/output-000000284.txt
#   inflating: img/output-000000290.txt
#   inflating: img/output-000000469.txt
#   inflating: img/output-000000033.jpg
#   inflating: img/output-000000027.jpg
#   inflating: img/output-000000741.jpg
#   inflating: img/output-000000455.txt
#   inflating: img/output-000000333.txt
#   inflating: img/output-000000327.txt
#   inflating: img/output-000000441.txt
#   inflating: img/output-000000496.txt
#   inflating: img/output-000000482.txt
#   inflating: img/output-000000231.jpg
#   inflating: img/output-000000557.jpg
#   inflating: img/output-000000543.jpg
#   inflating: img/output-000000119.txt
#   inflating: img/output-000000225.jpg
#   inflating: img/output-000000131.txt
#   inflating: img/output-000000657.txt
#   inflating: img/output-000000643.txt
#   inflating: img/output-000000219.jpg
#   inflating: img/output-000000125.txt
#   inflating: img/output-000000594.jpg
#   inflating: img/output-000000580.jpg
#   inflating: img/output-000000694.txt
#   inflating: img/output-000000680.txt
#   inflating: img/output-000000681.txt
#   inflating: img/output-000000695.txt
#   inflating: img/output-000000581.jpg
#   inflating: img/output-000000595.jpg
#   inflating: img/output-000000642.txt
#   inflating: img/output-000000124.txt
#   inflating: img/output-000000218.jpg
#   inflating: img/output-000000130.txt
#   inflating: img/output-000000656.txt
#   inflating: img/output-000000542.jpg
#   inflating: img/output-000000224.jpg
#   inflating: img/output-000000118.txt
#   inflating: img/output-000000230.jpg
#   inflating: img/output-000000556.jpg
#   inflating: img/output-000000483.txt
#   inflating: img/output-000000497.txt
#   inflating: img/output-000000326.txt
#   inflating: img/output-000000440.txt
#   inflating: img/output-000000454.txt
#   inflating: img/output-000000332.txt
#   inflating: img/output-000000026.jpg
#   inflating: img/output-000000740.jpg
#   inflating: img/output-000000468.txt
#   inflating: img/output-000000032.jpg
#   inflating: img/output-000000291.txt
#   inflating: img/output-000000285.txt
#   inflating: img/output-000000191.jpg
#   inflating: img/output-000000185.jpg
#   inflating: img/output-000000252.txt
#   inflating: img/output-000000534.txt
#   inflating: img/output-000000608.jpg
#   inflating: img/output-000000520.txt
#   inflating: img/output-000000246.txt
#   inflating: img/output-000000152.jpg
#   inflating: img/output-000000634.jpg
#   inflating: img/output-000000508.txt
#   inflating: img/output-000000620.jpg
#   inflating: img/output-000000146.jpg
#   inflating: img/output-000000093.txt
#   inflating: img/output-000000087.txt
#   inflating: img/output-000000393.jpg
#   inflating: img/output-000000387.jpg
#   inflating: img/output-000000736.txt
#   inflating: img/output-000000050.txt
#   inflating: img/output-000000378.jpg
#   inflating: img/output-000000044.txt
#   inflating: img/output-000000722.txt
#   inflating: img/output-000000436.jpg
#   inflating: img/output-000000350.jpg
#   inflating: img/output-000000078.txt
#   inflating: img/output-000000344.jpg
#   inflating: img/output-000000422.jpg
#   inflating: img/output-000000352.jpg
#   inflating: img/output-000000434.jpg
#   inflating: img/output-000000708.txt
#   inflating: img/output-000000420.jpg
#   inflating: img/output-000000346.jpg
#   inflating: img/output-000000052.txt
#   inflating: img/output-000000734.txt
#   inflating: img/output-000000408.jpg
#   inflating: img/output-000000720.txt
#   inflating: img/output-000000046.txt
#   inflating: img/output-000000391.jpg
#   inflating: img/output-000000385.jpg
#   inflating: img/output-000000091.txt
#   inflating: img/output-000000085.txt
#   inflating: img/output-000000636.jpg
#   inflating: img/output-000000150.jpg
#   inflating: img/output-000000278.txt
#   inflating: img/output-000000144.jpg
#   inflating: img/output-000000622.jpg
#   inflating: img/output-000000536.txt
#   inflating: img/output-000000250.txt
#   inflating: img/output-000000178.jpg
#   inflating: img/output-000000244.txt
#   inflating: img/output-000000522.txt
#   inflating: img/output-000000193.jpg
#   inflating: img/output-000000187.jpg
#   inflating: img/output-000000293.txt
#   inflating: img/output-000000287.txt
#   inflating: img/output-000000742.jpg
#   inflating: img/output-000000024.jpg
#   inflating: img/output-000000318.txt
#   inflating: img/output-000000030.jpg
#   inflating: img/output-000000442.txt
#   inflating: img/output-000000324.txt
#   inflating: img/output-000000018.jpg
#   inflating: img/output-000000330.txt
#   inflating: img/output-000000456.txt
#   inflating: img/output-000000481.txt
#   inflating: img/output-000000495.txt
#   inflating: img/output-000000226.jpg
#   inflating: img/output-000000540.jpg
#   inflating: img/output-000000668.txt
#   inflating: img/output-000000554.jpg
#   inflating: img/output-000000232.jpg
#   inflating: img/output-000000126.txt
#   inflating: img/output-000000640.txt
#   inflating: img/output-000000568.jpg
#   inflating: img/output-000000654.txt
#   inflating: img/output-000000132.txt
#   inflating: img/output-000000583.jpg
#   inflating: img/output-000000597.jpg
#   inflating: img/output-000000683.txt
#   inflating: img/output-000000697.txt
#   inflating: img/output-000000696.txt
#   inflating: img/output-000000682.txt
#   inflating: img/output-000000596.jpg
#   inflating: img/output-000000582.jpg
#   inflating: img/output-000000655.txt
#   inflating: img/output-000000569.jpg
#   inflating: img/output-000000133.txt
#   inflating: img/output-000000127.txt
#   inflating: img/output-000000641.txt
#   inflating: img/output-000000555.jpg
#   inflating: img/output-000000669.txt
#   inflating: img/output-000000233.jpg
#   inflating: img/output-000000227.jpg
#   inflating: img/output-000000541.jpg
#   inflating: img/output-000000494.txt
#   inflating: img/output-000000480.txt
#   inflating: img/output-000000331.txt
#   inflating: img/output-000000457.txt
#   inflating: img/output-000000443.txt
#   inflating: img/output-000000019.jpg
#   inflating: img/output-000000325.txt
#   inflating: img/output-000000031.jpg
#   inflating: img/output-000000743.jpg
#   inflating: img/output-000000319.txt
#   inflating: img/output-000000025.jpg
#   inflating: img/output-000000286.txt
#   inflating: img/output-000000292.txt
#   inflating: img/output-000000186.jpg
#   inflating: img/output-000000192.jpg
#   inflating: img/output-000000245.txt
#   inflating: img/output-000000179.jpg
#   inflating: img/output-000000523.txt
#   inflating: img/output-000000537.txt
#   inflating: img/output-000000251.txt
#   inflating: img/output-000000145.jpg
#   inflating: img/output-000000279.txt
#   inflating: img/output-000000623.jpg
#   inflating: img/output-000000637.jpg
#   inflating: img/output-000000151.jpg
#   inflating: img/output-000000084.txt
#   inflating: img/output-000000090.txt
#   inflating: img/output-000000384.jpg
#   inflating: img/output-000000390.jpg
#   inflating: img/output-000000721.txt
#   inflating: img/output-000000047.txt
#   inflating: img/output-000000053.txt
#   inflating: img/output-000000409.jpg
#   inflating: img/output-000000735.txt
#   inflating: img/output-000000421.jpg
#   inflating: img/output-000000347.jpg
#   inflating: img/output-000000353.jpg
#   inflating: img/output-000000709.txt
#   inflating: img/output-000000435.jpg
#   inflating: img/output-000000710.txt
#   inflating: img/output-000000076.txt
#   inflating: img/output-000000062.txt
#   inflating: img/output-000000704.txt
#   inflating: img/output-000000438.jpg
#   inflating: img/output-000000410.jpg
#   inflating: img/output-000000376.jpg
#   inflating: img/output-000000362.jpg
#   inflating: img/output-000000404.jpg
#   inflating: img/output-000000738.txt
#   inflating: img/output-000000389.jpg
#   inflating: img/output-000000089.txt
#   inflating: img/output-000000148.jpg
#   inflating: img/output-000000274.txt
#   inflating: img/output-000000512.txt
#   inflating: img/output-000000506.txt
#   inflating: img/output-000000260.txt
#   inflating: img/output-000000248.txt
#   inflating: img/output-000000174.jpg
#   inflating: img/output-000000612.jpg
#   inflating: img/output-000000606.jpg
#   inflating: img/output-000000160.jpg
#   inflating: img/output-000000300.txt
#   inflating: img/output-000000466.txt
#   inflating: img/output-000000472.txt
#   inflating: img/output-000000314.txt
#   inflating: img/output-000000028.jpg
#   inflating: img/output-000000014.jpg
#   inflating: img/output-000000328.txt
#   inflating: img/output-000000499.txt
#   inflating: img/output-000000558.jpg
#   inflating: img/output-000000664.txt
#   inflating: img/output-000000102.txt
#   inflating: img/output-000000116.txt
#   inflating: img/output-000000670.txt
#   inflating: img/output-000000658.txt
#   inflating: img/output-000000564.jpg
#   inflating: img/output-000000202.jpg
#   inflating: img/output-000000216.jpg
#   inflating: img/output-000000570.jpg
#   inflating: img/output-000000217.jpg
#   inflating: img/output-000000571.jpg
#   inflating: img/output-000000565.jpg
#   inflating: img/output-000000659.txt
#   inflating: img/output-000000203.jpg
#   inflating: img/output-000000117.txt
#   inflating: img/output-000000671.txt
#   inflating: img/output-000000665.txt
#   inflating: img/output-000000559.jpg
#   inflating: img/output-000000103.txt
#   inflating: img/output-000000498.txt
#   inflating: img/output-000000329.txt
#   inflating: img/output-000000015.jpg
#   inflating: img/output-000000001.jpg
#   inflating: img/output-000000473.txt
#   inflating: img/output-000000029.jpg
#   inflating: img/output-000000315.txt
#   inflating: img/output-000000301.txt
#   inflating: img/output-000000467.txt
#   inflating: img/output-000000607.jpg
#   inflating: img/output-000000161.jpg
#   inflating: img/output-000000175.jpg
#   inflating: img/output-000000249.txt
#   inflating: img/output-000000613.jpg
#   inflating: img/output-000000507.txt
#   inflating: img/output-000000261.txt
#   inflating: img/output-000000275.txt
#   inflating: img/output-000000149.jpg
#   inflating: img/output-000000513.txt
#   inflating: img/output-000000088.txt
#   inflating: img/output-000000388.jpg
#   inflating: img/output-000000363.jpg
#   inflating: img/output-000000739.txt
#   inflating: img/output-000000405.jpg
#   inflating: img/output-000000411.jpg
#   inflating: img/output-000000377.jpg
#   inflating: img/output-000000063.txt
#   inflating: img/output-000000439.jpg
#   inflating: img/output-000000705.txt
#   inflating: img/output-000000711.txt
#   inflating: img/output-000000077.txt
#   inflating: img/output-000000707.txt
#   inflating: img/output-000000061.txt
#   inflating: img/output-000000075.txt
#   inflating: img/output-000000349.jpg
#   inflating: img/output-000000713.txt
#   inflating: img/output-000000407.jpg
#   inflating: img/output-000000361.jpg
#   inflating: img/output-000000375.jpg
#   inflating: img/output-000000049.txt
#   inflating: img/output-000000413.jpg
#   inflating: img/output-000000263.txt
#   inflating: img/output-000000639.jpg
#   inflating: img/output-000000505.txt
#   inflating: img/output-000000511.txt
#   inflating: img/output-000000277.txt
#   inflating: img/output-000000163.jpg
#   inflating: img/output-000000539.txt
#   inflating: img/output-000000605.jpg
#   inflating: img/output-000000611.jpg
#   inflating: img/output-000000177.jpg
#   inflating: img/output-000000188.jpg
#   inflating: img/output-000000288.txt
#   inflating: img/output-000000317.txt
#   inflating: img/output-000000471.txt
#   inflating: img/output-000000465.txt
#   inflating: img/output-000000303.txt
#   inflating: img/output-000000017.jpg
#   inflating: img/output-000000459.txt
#   inflating: img/output-000000003.jpg
#   inflating: img/output-000000673.txt
#   inflating: img/output-000000229.jpg
#   inflating: img/output-000000115.txt
#   inflating: img/output-000000101.txt
#   inflating: img/output-000000667.txt
#   inflating: img/output-000000573.jpg
#   inflating: img/output-000000129.txt
#   inflating: img/output-000000215.jpg
#   inflating: img/output-000000201.jpg
#   inflating: img/output-000000567.jpg
#   inflating: img/output-000000598.jpg
#   inflating: img/output-000000698.txt
#   inflating: img/output-000000699.txt
#   inflating: img/output-000000599.jpg
#   inflating: img/output-000000200.jpg
#   inflating: img/output-000000566.jpg
#   inflating: img/output-000000572.jpg
#   inflating: img/output-000000214.jpg
#   inflating: img/output-000000128.txt
#   inflating: img/output-000000100.txt
#   inflating: img/output-000000666.txt
#   inflating: img/output-000000672.txt
#   inflating: img/output-000000114.txt
#   inflating: img/output-000000228.jpg
#   inflating: img/output-000000458.txt
#   inflating: img/output-000000002.jpg
#   inflating: img/output-000000016.jpg
#   inflating: img/output-000000464.txt
#   inflating: img/output-000000302.txt
#   inflating: img/output-000000316.txt
#   inflating: img/output-000000470.txt
#   inflating: img/output-000000289.txt
#   inflating: img/output-000000189.jpg
#   inflating: img/output-000000610.jpg
#   inflating: img/output-000000176.jpg
#   inflating: img/output-000000162.jpg
#   inflating: img/output-000000604.jpg
#   inflating: img/output-000000538.txt
#   inflating: img/output-000000510.txt
#   inflating: img/output-000000276.txt
#   inflating: img/output-000000262.txt
#   inflating: img/output-000000504.txt
#   inflating: img/output-000000638.jpg
#   inflating: img/output-000000048.txt
#   inflating: img/output-000000374.jpg
#   inflating: img/output-000000412.jpg
#   inflating: img/output-000000406.jpg
#   inflating: img/output-000000360.jpg
#   inflating: img/output-000000348.jpg
#   inflating: img/output-000000074.txt
#   inflating: img/output-000000712.txt
#   inflating: img/output-000000706.txt
#   inflating: img/output-000000060.txt
#   inflating: img/output-000000058.txt
#   inflating: img/output-000000364.jpg
#   inflating: img/output-000000402.jpg
#   inflating: img/output-000000416.jpg
#   inflating: img/output-000000370.jpg
#   inflating: img/output-000000358.jpg
#   inflating: img/output-000000064.txt
#   inflating: img/output-000000702.txt
#   inflating: img/output-000000716.txt
#   inflating: img/output-000000070.txt
#   inflating: img/output-000000600.jpg
#   inflating: img/output-000000166.jpg
#   inflating: img/output-000000172.jpg
#   inflating: img/output-000000614.jpg
#   inflating: img/output-000000528.txt
#   inflating: img/output-000000500.txt
#   inflating: img/output-000000266.txt
#   inflating: img/output-000000272.txt
#   inflating: img/output-000000514.txt
#   inflating: img/output-000000628.jpg
#   inflating: img/output-000000299.txt
#   inflating: img/output-000000199.jpg
#   inflating: img/output-000000448.txt
#   inflating: img/output-000000012.jpg
#   inflating: img/output-000000006.jpg
#   inflating: img/output-000000748.jpg
#   inflating: img/output-000000474.txt
#   inflating: img/output-000000312.txt
#   inflating: img/output-000000306.txt
#   inflating: img/output-000000460.txt
#   inflating: img/output-000000210.jpg
#   inflating: img/output-000000576.jpg
#   inflating: img/output-000000562.jpg
#   inflating: img/output-000000204.jpg
#   inflating: img/output-000000138.txt
#   inflating: img/output-000000110.txt
#   inflating: img/output-000000676.txt
#   inflating: img/output-000000662.txt
#   inflating: img/output-000000104.txt
#   inflating: img/output-000000238.jpg
#   inflating: img/output-000000689.txt
#   inflating: img/output-000000589.jpg
#   inflating: img/output-000000588.jpg
#   inflating: img/output-000000688.txt
#   inflating: img/output-000000663.txt
#   inflating: img/output-000000239.jpg
#   inflating: img/output-000000105.txt
#   inflating: img/output-000000111.txt
#   inflating: img/output-000000677.txt
#   inflating: img/output-000000563.jpg
#   inflating: img/output-000000139.txt
#   inflating: img/output-000000205.jpg
#   inflating: img/output-000000211.jpg
#   inflating: img/output-000000577.jpg
#   inflating: img/output-000000307.txt
#   inflating: img/output-000000461.txt
#   inflating: img/output-000000475.txt
#   inflating: img/output-000000749.jpg
#   inflating: img/output-000000313.txt
#   inflating: img/output-000000007.jpg
#   inflating: img/output-000000449.txt
#   inflating: img/output-000000013.jpg
#   inflating: img/output-000000198.jpg
#   inflating: img/output-000000298.txt
#   inflating: img/output-000000273.txt
#   inflating: img/output-000000629.jpg
#   inflating: img/output-000000515.txt
#   inflating: img/output-000000501.txt
#   inflating: img/output-000000267.txt
#   inflating: img/output-000000173.jpg
#   inflating: img/output-000000529.txt
#   inflating: img/output-000000615.jpg
#   inflating: img/output-000000601.jpg
#   inflating: img/output-000000167.jpg
#   inflating: img/output-000000717.txt
#   inflating: img/output-000000071.txt
#   inflating: img/output-000000065.txt
#   inflating: img/output-000000359.jpg
#   inflating: img/output-000000703.txt
#   inflating: img/output-000000417.jpg
#   inflating: img/output-000000371.jpg
#   inflating: img/output-000000365.jpg
#   inflating: img/output-000000059.txt
#   inflating: img/output-000000403.jpg
#   inflating: img/output-000000373.jpg
#   inflating: img/output-000000729.txt
#   inflating: img/output-000000415.jpg
#   inflating: img/output-000000401.jpg
#   inflating: img/output-000000367.jpg
#   inflating: img/output-000000073.txt
#   inflating: img/output-000000429.jpg
#   inflating: img/output-000000715.txt
#   inflating: img/output-000000701.txt
#   inflating: img/output-000000067.txt
#   inflating: img/output-000000098.txt
#   inflating: img/output-000000398.jpg
#   inflating: img/output-000000617.jpg
#   inflating: img/output-000000171.jpg
#   inflating: img/output-000000165.jpg
#   inflating: img/output-000000259.txt
#   inflating: img/output-000000603.jpg
#   inflating: img/output-000000517.txt
#   inflating: img/output-000000271.txt
#   inflating: img/output-000000265.txt
#   inflating: img/output-000000159.jpg
#   inflating: img/output-000000503.txt
#   inflating: img/output-000000339.txt
#   inflating: img/output-000000005.jpg
#   inflating: img/output-000000011.jpg
#   inflating: img/output-000000463.txt
#   inflating: img/output-000000039.jpg
#   inflating: img/output-000000305.txt
#   inflating: img/output-000000311.txt
#   inflating: img/output-000000477.txt
#   inflating: img/output-000000488.txt
#   inflating: img/output-000000207.jpg
#   inflating: img/output-000000561.jpg
#   inflating: img/output-000000575.jpg
#   inflating: img/output-000000649.txt
#   inflating: img/output-000000213.jpg
#   inflating: img/output-000000107.txt
#   inflating: img/output-000000661.txt
#   inflating: img/output-000000675.txt
#   inflating: img/output-000000549.jpg
#   inflating: img/output-000000113.txt
#   inflating: img/output-000000548.jpg
#   inflating: img/output-000000674.txt
#   inflating: img/output-000000112.txt
#   inflating: img/output-000000106.txt
#   inflating: img/output-000000660.txt
#   inflating: img/output-000000648.txt
#   inflating: img/output-000000574.jpg
#   inflating: img/output-000000212.jpg
#   inflating: img/output-000000206.jpg
#   inflating: img/output-000000560.jpg
#   inflating: img/output-000000489.txt
#   inflating: img/output-000000310.txt
#   inflating: img/output-000000476.txt
#   inflating: img/output-000000462.txt
#   inflating: img/output-000000304.txt
#   inflating: img/output-000000038.jpg
#   inflating: img/output-000000010.jpg
#   inflating: img/output-000000004.jpg
#   inflating: img/output-000000338.txt
#   inflating: img/output-000000158.jpg
#   inflating: img/output-000000264.txt
#   inflating: img/output-000000502.txt
#   inflating: img/output-000000516.txt
#   inflating: img/output-000000270.txt
#   inflating: img/output-000000258.txt
#   inflating: img/output-000000164.jpg
#   inflating: img/output-000000602.jpg
#   inflating: img/output-000000616.jpg
#   inflating: img/output-000000170.jpg
#   inflating: img/output-000000399.jpg
#   inflating: img/output-000000099.txt
#   inflating: img/output-000000700.txt
#   inflating: img/output-000000066.txt
#   inflating: img/output-000000072.txt
#   inflating: img/output-000000714.txt
#   inflating: img/output-000000428.jpg
#   inflating: img/output-000000400.jpg
#   inflating: img/output-000000366.jpg
#   inflating: img/output-000000372.jpg
#   inflating: img/output-000000414.jpg
#   inflating: img/output-000000728.txt
#   inflating: img/output-000000329.jpg
#   inflating: img/output-000000015.txt
#   inflating: img/output-000000001.txt
#   inflating: img/output-000000029.txt
#   inflating: img/output-000000315.jpg
#   inflating: img/output-000000473.jpg
#   inflating: img/output-000000467.jpg
#   inflating: img/output-000000301.jpg
#   inflating: img/output-000000498.jpg
#   inflating: img/output-000000571.txt
#   inflating: img/output-000000217.txt
#   inflating: img/output-000000203.txt
#   inflating: img/output-000000565.txt
#   inflating: img/output-000000659.jpg
#   inflating: img/output-000000671.jpg
#   inflating: img/output-000000117.jpg
#   inflating: img/output-000000103.jpg
#   inflating: img/output-000000665.jpg
#   inflating: img/output-000000559.txt
#   inflating: img/output-000000739.jpg
#   inflating: img/output-000000405.txt
#   inflating: img/output-000000363.txt
#   inflating: img/output-000000377.txt
#   inflating: img/output-000000411.txt
#   inflating: img/output-000000439.txt
#   inflating: img/output-000000705.jpg
#   inflating: img/output-000000063.jpg
#   inflating: img/output-000000077.jpg
#   inflating: img/output-000000711.jpg
#   inflating: img/output-000000088.jpg
#   inflating: img/output-000000388.txt
#   inflating: img/output-000000161.txt
#   inflating: img/output-000000607.txt
#   inflating: img/output-000000613.txt
#   inflating: img/output-000000175.txt
#   inflating: img/output-000000249.jpg
#   inflating: img/output-000000261.jpg
#   inflating: img/output-000000507.jpg
#   inflating: img/output-000000513.jpg
#   inflating: img/output-000000275.jpg
#   inflating: img/output-000000149.txt
#   inflating: img/output-000000512.jpg
#   inflating: img/output-000000148.txt
#   inflating: img/output-000000274.jpg
#   inflating: img/output-000000260.jpg
#   inflating: img/output-000000506.jpg
#   inflating: img/output-000000612.txt
#   inflating: img/output-000000248.jpg
#   inflating: img/output-000000174.txt
#   inflating: img/output-000000160.txt
#   inflating: img/output-000000606.txt
#   inflating: img/output-000000389.txt
#   inflating: img/output-000000089.jpg
#   inflating: img/output-000000076.jpg
#   inflating: img/output-000000710.jpg
#   inflating: img/output-000000704.jpg
#   inflating: img/output-000000438.txt
#   inflating: img/output-000000062.jpg
#   inflating: img/output-000000376.txt
#   inflating: img/output-000000410.txt
#   inflating: img/output-000000404.txt
#   inflating: img/output-000000738.jpg
#   inflating: img/output-000000362.txt
#   inflating: img/output-000000102.jpg
#   inflating: img/output-000000558.txt
#   inflating: img/output-000000664.jpg
#   inflating: img/output-000000670.jpg
#   inflating: img/output-000000116.jpg
#   inflating: img/output-000000202.txt
#   inflating: img/output-000000658.jpg
#   inflating: img/output-000000564.txt
#   inflating: img/output-000000570.txt
#   inflating: img/output-000000216.txt
#   inflating: img/output-000000499.jpg
#   inflating: img/output-000000466.jpg
#   inflating: img/output-000000300.jpg
#   inflating: img/output-000000314.jpg
#   inflating: img/output-000000028.txt
#   inflating: img/output-000000472.jpg
#   inflating: img/output-000000014.txt
#   inflating: img/output-000000328.jpg
#   inflating: img/output-000000002.txt
#   inflating: img/output-000000458.jpg
#   inflating: img/output-000000016.txt
#   inflating: img/output-000000302.jpg
#   inflating: img/output-000000464.jpg
#   inflating: img/output-000000470.jpg
#   inflating: img/output-000000316.jpg
#   inflating: img/output-000000566.txt
#   inflating: img/output-000000200.txt
#   inflating: img/output-000000214.txt
#   inflating: img/output-000000128.jpg
#   inflating: img/output-000000572.txt
#   inflating: img/output-000000666.jpg
#   inflating: img/output-000000100.jpg
#   inflating: img/output-000000114.jpg
#   inflating: img/output-000000228.txt
#   inflating: img/output-000000672.jpg
#   inflating: img/output-000000699.jpg
#   inflating: img/output-000000599.txt
#   inflating: img/output-000000412.txt
#   inflating: img/output-000000048.jpg
#   inflating: img/output-000000374.txt
#   inflating: img/output-000000360.txt
#   inflating: img/output-000000406.txt
#   inflating: img/output-000000712.jpg
#   inflating: img/output-000000348.txt
#   inflating: img/output-000000074.jpg
#   inflating: img/output-000000060.jpg
#   inflating: img/output-000000706.jpg
#   inflating: img/output-000000176.txt
#   inflating: img/output-000000610.txt
#   inflating: img/output-000000604.txt
#   inflating: img/output-000000538.jpg
#   inflating: img/output-000000162.txt
#   inflating: img/output-000000276.jpg
#   inflating: img/output-000000510.jpg
#   inflating: img/output-000000504.jpg
#   inflating: img/output-000000638.txt
#   inflating: img/output-000000262.jpg
#   inflating: img/output-000000289.jpg
#   inflating: img/output-000000189.txt
#   inflating: img/output-000000188.txt
#   inflating: img/output-000000288.jpg
#   inflating: img/output-000000639.txt
#   inflating: img/output-000000505.jpg
#   inflating: img/output-000000263.jpg
#   inflating: img/output-000000277.jpg
#   inflating: img/output-000000511.jpg
#   inflating: img/output-000000539.jpg
#   inflating: img/output-000000605.txt
#   inflating: img/output-000000163.txt
#   inflating: img/output-000000177.txt
#   inflating: img/output-000000611.txt
#   inflating: img/output-000000061.jpg
#   inflating: img/output-000000707.jpg
#   inflating: img/output-000000713.jpg
#   inflating: img/output-000000075.jpg
#   inflating: img/output-000000349.txt
#   inflating: img/output-000000361.txt
#   inflating: img/output-000000407.txt
#   inflating: img/output-000000413.txt
#   inflating: img/output-000000375.txt
#   inflating: img/output-000000049.jpg
#   inflating: img/output-000000598.txt
#   inflating: img/output-000000698.jpg
#   inflating: img/output-000000229.txt
#   inflating: img/output-000000115.jpg
#   inflating: img/output-000000673.jpg
#   inflating: img/output-000000667.jpg
#   inflating: img/output-000000101.jpg
#   inflating: img/output-000000129.jpg
#   inflating: img/output-000000215.txt
#   inflating: img/output-000000573.txt
#   inflating: img/output-000000567.txt
#   inflating: img/output-000000201.txt
#   inflating: img/output-000000471.jpg
#   inflating: img/output-000000317.jpg
#   inflating: img/output-000000303.jpg
#   inflating: img/output-000000465.jpg
#   inflating: img/output-000000017.txt
#   inflating: img/output-000000003.txt
#   inflating: img/output-000000459.jpg
#   inflating: img/output-000000461.jpg
#   inflating: img/output-000000307.jpg
#   inflating: img/output-000000313.jpg
#   inflating: img/output-000000475.jpg
#   inflating: img/output-000000749.txt
#   inflating: img/output-000000007.txt
#   inflating: img/output-000000013.txt
#   inflating: img/output-000000449.jpg
#   inflating: img/output-000000239.txt
#   inflating: img/output-000000105.jpg
#   inflating: img/output-000000663.jpg
#   inflating: img/output-000000677.jpg
#   inflating: img/output-000000111.jpg
#   inflating: img/output-000000139.jpg
#   inflating: img/output-000000205.txt
#   inflating: img/output-000000563.txt
#   inflating: img/output-000000577.txt
#   inflating: img/output-000000211.txt
#   inflating: img/output-000000588.txt
#   inflating: img/output-000000688.jpg
#   inflating: img/output-000000071.jpg
#   inflating: img/output-000000717.jpg
#   inflating: img/output-000000703.jpg
#   inflating: img/output-000000065.jpg
#   inflating: img/output-000000359.txt
#   inflating: img/output-000000371.txt
#   inflating: img/output-000000417.txt
#   inflating: img/output-000000403.txt
#   inflating: img/output-000000365.txt
#   inflating: img/output-000000059.jpg
#   inflating: img/output-000000629.txt
#   inflating: img/output-000000515.jpg
#   inflating: img/output-000000273.jpg
#   inflating: img/output-000000267.jpg
#   inflating: img/output-000000501.jpg
#   inflating: img/output-000000529.jpg
#   inflating: img/output-000000615.txt
#   inflating: img/output-000000173.txt
#   inflating: img/output-000000167.txt
#   inflating: img/output-000000601.txt
#   inflating: img/output-000000198.txt
#   inflating: img/output-000000298.jpg
#   inflating: img/output-000000299.jpg
#   inflating: img/output-000000199.txt
#   inflating: img/output-000000166.txt
#   inflating: img/output-000000600.txt
#   inflating: img/output-000000614.txt
#   inflating: img/output-000000528.jpg
#   inflating: img/output-000000172.txt
#   inflating: img/output-000000266.jpg
#   inflating: img/output-000000500.jpg
#   inflating: img/output-000000514.jpg
#   inflating: img/output-000000628.txt
#   inflating: img/output-000000272.jpg
#   inflating: img/output-000000402.txt
#   inflating: img/output-000000058.jpg
#   inflating: img/output-000000364.txt
#   inflating: img/output-000000370.txt
#   inflating: img/output-000000416.txt
#   inflating: img/output-000000702.jpg
#   inflating: img/output-000000358.txt
#   inflating: img/output-000000064.jpg
#   inflating: img/output-000000070.jpg
#   inflating: img/output-000000716.jpg
#   inflating: img/output-000000689.jpg
#   inflating: img/output-000000589.txt
#   inflating: img/output-000000576.txt
#   inflating: img/output-000000210.txt
#   inflating: img/output-000000204.txt
#   inflating: img/output-000000138.jpg
#   inflating: img/output-000000562.txt
#   inflating: img/output-000000676.jpg
#   inflating: img/output-000000110.jpg
#   inflating: img/output-000000104.jpg
#   inflating: img/output-000000238.txt
#   inflating: img/output-000000662.jpg
#   inflating: img/output-000000012.txt
#   inflating: img/output-000000448.jpg
#   inflating: img/output-000000006.txt
#   inflating: img/output-000000312.jpg
#   inflating: img/output-000000748.txt
#   inflating: img/output-000000474.jpg
#   inflating: img/output-000000460.jpg
#   inflating: img/output-000000306.jpg
#   inflating: img/output-000000476.jpg
#   inflating: img/output-000000310.jpg
#   inflating: img/output-000000304.jpg
#   inflating: img/output-000000038.txt
#   inflating: img/output-000000462.jpg
#   inflating: img/output-000000010.txt
#   inflating: img/output-000000004.txt
#   inflating: img/output-000000338.jpg
#   inflating: img/output-000000489.jpg
#   inflating: img/output-000000112.jpg
#   inflating: img/output-000000548.txt
#   inflating: img/output-000000674.jpg
#   inflating: img/output-000000660.jpg
#   inflating: img/output-000000106.jpg
#   inflating: img/output-000000212.txt
#   inflating: img/output-000000648.jpg
#   inflating: img/output-000000574.txt
#   inflating: img/output-000000560.txt
#   inflating: img/output-000000206.txt
#   inflating: img/output-000000066.jpg
#   inflating: img/output-000000700.jpg
#   inflating: img/output-000000714.jpg
#   inflating: img/output-000000428.txt
#   inflating: img/output-000000072.jpg
#   inflating: img/output-000000366.txt
#   inflating: img/output-000000400.txt
#   inflating: img/output-000000414.txt
#   inflating: img/output-000000728.jpg
#   inflating: img/output-000000372.txt
#   inflating: img/output-000000399.txt
#   inflating: img/output-000000099.jpg
#   inflating: img/output-000000502.jpg
#   inflating: img/output-000000158.txt
#   inflating: img/output-000000264.jpg
#   inflating: img/output-000000270.jpg
#   inflating: img/output-000000516.jpg
#   inflating: img/output-000000602.txt
#   inflating: img/output-000000258.jpg
#   inflating: img/output-000000164.txt
#   inflating: img/output-000000170.txt
#   inflating: img/output-000000616.txt
#   inflating: img/output-000000171.txt
#   inflating: img/output-000000617.txt
#   inflating: img/output-000000603.txt
#   inflating: img/output-000000165.txt
#   inflating: img/output-000000259.jpg
#   inflating: img/output-000000271.jpg
#   inflating: img/output-000000517.jpg
#   inflating: img/output-000000503.jpg
#   inflating: img/output-000000265.jpg
#   inflating: img/output-000000159.txt
#   inflating: img/output-000000098.jpg
#   inflating: img/output-000000398.txt
#   inflating: img/output-000000729.jpg
#   inflating: img/output-000000415.txt
#   inflating: img/output-000000373.txt
#   inflating: img/output-000000367.txt
#   inflating: img/output-000000401.txt
#   inflating: img/output-000000429.txt
#   inflating: img/output-000000715.jpg
#   inflating: img/output-000000073.jpg
#   inflating: img/output-000000067.jpg
#   inflating: img/output-000000701.jpg
#   inflating: img/output-000000561.txt
#   inflating: img/output-000000207.txt
#   inflating: img/output-000000213.txt
#   inflating: img/output-000000575.txt
#   inflating: img/output-000000649.jpg
#   inflating: img/output-000000661.jpg
#   inflating: img/output-000000107.jpg
#   inflating: img/output-000000113.jpg
#   inflating: img/output-000000675.jpg
#   inflating: img/output-000000549.txt
#   inflating: img/output-000000488.jpg
#   inflating: img/output-000000339.jpg
#   inflating: img/output-000000005.txt
#   inflating: img/output-000000011.txt
#   inflating: img/output-000000039.txt
#   inflating: img/output-000000305.jpg
#   inflating: img/output-000000463.jpg
#   inflating: img/output-000000477.jpg
#   inflating: img/output-000000311.jpg
#   inflating: obj.names
#   inflating: __MACOSX/._obj.names

# %%
# either make changes manually or run the below code
os.chdir("/content/darknet")
# !sed -i 's/batch=1/batch=64/g' cfg/yolov3.cfg
# !sed -i 's/subdivisions=1/subdivisions=32/g' cfg/yolov3.cfg
# !sed -i 's/max_batches = 500200/max_batches = 5000/g' cfg/yolov3.cfg
# !sed -i 's/steps=400000,450000/steps=4000,5000/g' cfg/yolov3.cfg
# !sed -i 's/classes=80/classes=5/g' cfg/yolov3.cfg
# !sed -i 's/filters=255/filters=30/g' cfg/yolov3.cfg
# !cat cfg/yolov3.cfg
# Out:
# [net]
# # Testing
# batch=64
# subdivisions=32
# # Training
# # batch=64
# # subdivisions=326
# width=416
# height=416
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
#
# learning_rate=0.001
# burn_in=1000
# max_batches = 5000
# policy=steps
# steps=4000,5000
# scales=.1,.1
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# ######################
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
#
# [convolutional]
# size=1
# stride=1
# pad=1
# filters=30
# activation=linear
#
#
# [yolo]
# mask = 6,7,8
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=5
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
#
#
# [route]
# layers = -4
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [upsample]
# stride=2
#
# [route]
# layers = -1, 61
#
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
#
# [convolutional]
# size=1
# stride=1
# pad=1
# filters=30
# activation=linear
#
#
# [yolo]
# mask = 3,4,5
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=5
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
#
#
#
# [route]
# layers = -4
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [upsample]
# stride=2
#
# [route]
# layers = -1, 36
#
#
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
#
# [convolutional]
# size=1
# stride=1
# pad=1
# filters=30
# activation=linear
#
#
# [yolo]
# mask = 0,1,2
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=5
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1

# %%
os.chdir("/content/darknet")
# use the line below to retrain your previous saved weight
# !./darknet detector train data/obj.data cfg/yolov3.cfg darknet53.conv.74
# Out:
# Streaming output truncated to the last 5000 lines.
#  342: -nan, nan avg loss, 0.000014 rate, 10.898791 seconds, 21888 images, 12.657122 hours left
# Loaded: 0.000034 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59067, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59072, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 5, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59080, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 5, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59089, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59095, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59097, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59102, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59106, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59111, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 5, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59117, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59123, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59129, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59134, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59139, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59144, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 6, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59152, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59156, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59162, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59166, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59173, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59180, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59185, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59190, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59197, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59204, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59209, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59215, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59221, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59225, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59230, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59234, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59237, rewritten_bbox = 0.000000 %
#
#  343: -nan, nan avg loss, 0.000014 rate, 10.992242 seconds, 21952 images, 12.671570 hours left
# Loaded: 0.000033 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59241, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59247, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59253, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59257, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59261, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59270, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59278, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59286, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59290, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59295, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 5, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59302, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 5, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59309, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59315, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59321, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59326, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59330, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59335, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59341, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59345, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59351, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59355, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59359, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59365, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59369, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59376, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59380, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 6, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59386, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59390, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59395, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59401, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59407, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59413, rewritten_bbox = 0.000000 %
#
#  344: -nan, nan avg loss, 0.000014 rate, 10.913987 seconds, 22016 images, 12.687052 hours left
# Loaded: 0.000029 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59419, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59426, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59431, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59435, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59440, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59447, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59450, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59454, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59459, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59463, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 6, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59471, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59476, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59480, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59482, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59487, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59493, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59499, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59505, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59511, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59518, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59524, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59530, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59535, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59540, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59545, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59551, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 59557, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# ...
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65357, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65361, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 5, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65367, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65373, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65379, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 7, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65387, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65392, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65396, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65401, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65407, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65412, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 6, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65419, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 6, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65429, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65433, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65438, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 5, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65446, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65450, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65455, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 5, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65460, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65469, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65474, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 5, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65481, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65485, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = nan, total_loss = nan
#  total_bbox = 65492, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65500, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65505, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65511, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 4, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65516, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65519, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65521, rewritten_bbox = 0.000000 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 3, class_loss = -nan, iou_loss = nan, total_loss = nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.000000), count: 2, class_loss = -nan, iou_loss = -nan, total_loss = -nan
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = -nan, iou_loss = -nan, total_loss = -nan
#  total_bbox = 65526, rewritten_bbox = 0.000000 %
#
#  380: nan, nan avg loss, 0.000021 rate, 12.326091 seconds, 24320 images, 13.854417 hours left
# Resizing, random_coef = 1.40
#
#  608 x 608
#  try to allocate additional workspace_size = 106.46 MB
#  CUDA allocate done!
# Loaded: 0.000038 seconds

# %%
os.getcwd()
# Out:
# '/content/darknet'

# %%
os.chdir("/content/darknet")
# !wget -q https://cdn.pixabay.com/photo/2016/09/13/16/21/colorful-1667624_960_720.jpg

# %%
os.chdir("/content/darknet")

# %%
import cv2

# %%
import numpy as np
import argparse
import time
import cv2
import os
import matplotlib.pyplot as plt


img_name = "colorful-1667624_960_720.jpg"
confidence_val = 0.1 # for confidence filtering of object detection
threshold = 0.8 # for NMS

LABELS = open("data/obj.names").read().strip().split("\n")
# initialize a list of colors to represent each possible class label
np.random.seed(42)
COLORS = np.random.randint(0, 255, size=(len(LABELS), 3),dtype="uint8")
print(LABELS)
# derive the paths to the YOLO weights and model configuration
weightsPath = "backup/yolov3_last.weights"
configPath = "cfg/yolov3.cfg"
# load our YOLO object detector trained on COCO dataset (80 classes)
print("[INFO] loading YOLO from disk...")
net = cv2.dnn.readNetFromDarknet(configPath, weightsPath)

image = cv2.imread(img_name)
(H, W) = image.shape[:2]
# determine only the *output* layer names that we need from YOLO
ln = net.getLayerNames()
ln = [ln[i[0] - 1] for i in net.getUnconnectedOutLayers()]
# construct a blob from the input image and then perform a forward
# pass of the YOLO object detector, giving us our bounding boxes and
# associated probabilities
blob = cv2.dnn.blobFromImage(image, 1 / 255.0, (416, 416),
	swapRB=True, crop=False)
net.setInput(blob)
start = time.time()
layerOutputs = net.forward(ln)
end = time.time()
# show timing information on YOLO
print("[INFO] YOLO took {:.6f} seconds".format(end - start))
# initialize our lists of detected bounding boxes, confidences, and
# class IDs, respectively
boxes = []
confidences = []
classIDs = []


# loop over each of the layer outputs
for output in layerOutputs:
	# loop over each of the detections
	for detection in output:
		# extract the class ID and confidence (i.e., probability) of
		# the current object detection
		scores = detection[5:]
		classID = np.argmax(scores)
		confidence = scores[classID]
		# filter out weak predictions by ensuring the detected
		# probability is greater than the minimum probability
		if confidence > confidence_val:
			# scale the bounding box coordinates back relative to the
			# size of the image, keeping in mind that YOLO actually
			# returns the center (x, y)-coordinates of the bounding
			# box followed by the boxes' width and height
			box = detection[0:4] * np.array([W, H, W, H])
			(centerX, centerY, width, height) = box.astype("int")
			# use the center (x, y)-coordinates to derive the top and
			# and left corner of the bounding box
			x = int(centerX - (width / 2))
			y = int(centerY - (height / 2))
			# update our list of bounding box coordinates, confidences,
			# and class IDs
			boxes.append([x, y, int(width), int(height)])
			confidences.append(float(confidence))
			classIDs.append(classID)
   
# apply non-maxima suppression to suppress weak, overlapping bounding
# boxes
idxs = cv2.dnn.NMSBoxes(boxes, confidences, confidence_val,threshold)

# ensure at least one detection exists
if len(idxs) > 0:
	# loop over the indexes we are keeping
	for i in idxs.flatten():
		# extract the bounding box coordinates
		(x, y) = (boxes[i][0], boxes[i][1])
		(w, h) = (boxes[i][2], boxes[i][3])
		# draw a bounding box rectangle and label on the image
		color = [int(c) for c in COLORS[classIDs[i]]]
		cv2.rectangle(image, (x, y), (x + w, y + h), color, 5)
		text = "{}: {:.4f}".format(LABELS[classIDs[i]], confidences[i])
		cv2.putText(image, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX,
			0.5, color, 2)
# show the output image
plt.imshow(image)
plt.show()
# Out:
# ['Tug', 'Ferry', 'Sailboat', 'Cruise', 'Unknown']
# [INFO] loading YOLO from disk...
# [INFO] YOLO took 1.793743 seconds

# %%
img = plt.imread(img_name)
plt.imshow(img)
plt.show()
