# %% [markdown]
# <a href="https://colab.research.google.com/github/anshupandey/Computer-Vision/blob/master/object%20detection/YOLO/YOLO_code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **YOLO**

# %% [markdown]
# # Installing Darknet

# %%
# !git clone https://github.com/AlexeyAB/darknet
import os
os.chdir("/content/darknet")
# Out:
# Cloning into 'darknet'...
# remote: Enumerating objects: 15395, done.
# remote: Total 15395 (delta 0), reused 0 (delta 0), pack-reused 15395
# Receiving objects: 100% (15395/15395), 14.02 MiB | 21.71 MiB/s, done.
# Resolving deltas: 100% (10353/10353), done.

# %%
# Compiling darknet
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !cat Makefile
# !make

# %% [markdown]
# ## Downloading the pre trained YOLO model

# %%
# downloading YOLO model
os.chdir("/content/darknet")
# !wget -q https://www.dropbox.com/s/m3tg61e1wsvawoq/darknet53.conv.74
# Out:
# --2022-02-03 05:46:31--  https://www.dropbox.com/s/m3tg61e1wsvawoq/darknet53.conv.74
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601d:18::a27d:512
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/m3tg61e1wsvawoq/darknet53.conv.74 [following]
# --2022-02-03 05:46:32--  https://www.dropbox.com/s/raw/m3tg61e1wsvawoq/darknet53.conv.74
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucc46d0705407cd594a9346f1831.dl.dropboxusercontent.com/cd/0/inline/Be99XKI5_QvVYrEMejlw9P2RNr3vHGJXytMZlmuaDnqYjxSZwHfZeaoNQ09msSD936IsP3RCPABmY53BenOAxZFPtKv_gonXNpgtlirEFaNI0mVFW1XctlqxwsAJUajjXoiwr8rxLSIGB0zY8-_WkF9b/file# [following]
# --2022-02-03 05:46:32--  https://ucc46d0705407cd594a9346f1831.dl.dropboxusercontent.com/cd/0/inline/Be99XKI5_QvVYrEMejlw9P2RNr3vHGJXytMZlmuaDnqYjxSZwHfZeaoNQ09msSD936IsP3RCPABmY53BenOAxZFPtKv_gonXNpgtlirEFaNI0mVFW1XctlqxwsAJUajjXoiwr8rxLSIGB0zY8-_WkF9b/file
# Resolving ucc46d0705407cd594a9346f1831.dl.dropboxusercontent.com (ucc46d0705407cd594a9346f1831.dl.dropboxusercontent.com)... 162.125.5.15, 2620:100:601d:15::a27d:50f
# Connecting to ucc46d0705407cd594a9346f1831.dl.dropboxusercontent.com (ucc46d0705407cd594a9346f1831.dl.dropboxusercontent.com)|162.125.5.15|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /cd/0/inline2/Be_PI2UIMtD7xLgM4jq0snS5Skv2AU4vmZLLkrVtWJ15S4Kc2YI6rEQ6S1txWZYGGL7iGcptQUzYrRRtCJ2ZKF9VjuXr5LYY9uySXH0S92dtstNwOfyJwAnSIYNtixLX2qrVzcftU7OlW5VQJIrycxK6uiN36IrrQh1bzPePPH6R0BBDp3c_msGhOXsrLRXtJZMw4My5XMMX2Ct5M2twYfbExpGnI2kop9mB08FI4lF0dzHVMFnAqq8HGHZJPYCDIoJUrFxuNH710XFu6SbmseZZkFrtZGvZnLZynCi-3CTxDHCkfHAh85yuSR-myDbiiB54cka9oqXx9S6LZXoT3sa2AhtkRJvsxa7TcIZ3jro7_ZGmxsSghNwWf7lZJEsh4wc/file [following]
# --2022-02-03 05:46:32--  https://ucc46d0705407cd594a9346f1831.dl.dropboxusercontent.com/cd/0/inline2/Be_PI2UIMtD7xLgM4jq0snS5Skv2AU4vmZLLkrVtWJ15S4Kc2YI6rEQ6S1txWZYGGL7iGcptQUzYrRRtCJ2ZKF9VjuXr5LYY9uySXH0S92dtstNwOfyJwAnSIYNtixLX2qrVzcftU7OlW5VQJIrycxK6uiN36IrrQh1bzPePPH6R0BBDp3c_msGhOXsrLRXtJZMw4My5XMMX2Ct5M2twYfbExpGnI2kop9mB08FI4lF0dzHVMFnAqq8HGHZJPYCDIoJUrFxuNH710XFu6SbmseZZkFrtZGvZnLZynCi-3CTxDHCkfHAh85yuSR-myDbiiB54cka9oqXx9S6LZXoT3sa2AhtkRJvsxa7TcIZ3jro7_ZGmxsSghNwWf7lZJEsh4wc/file
# Reusing existing connection to ucc46d0705407cd594a9346f1831.dl.dropboxusercontent.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 162482580 (155M) [application/octet-stream]
# Saving to: ‘darknet53.conv.74’
#
# darknet53.conv.74   100%[===================>] 154.96M  53.2MB/s    in 2.9s
#
# 2022-02-03 05:46:36 (53.2 MB/s) - ‘darknet53.conv.74’ saved [162482580/162482580]

# %% [markdown]
# ## Downloading a dataset

# %%
os.chdir("/content/darknet/data")
# !wget -q https://www.dropbox.com/s/v2gmvmup24m5kzq/yolo-dataset.zip

# %%
# !unzip -q yolo-dataset.zip

# %% [markdown]
# ## Configuration for training

# %%
# either make changes manually or run the below code
os.chdir("/content/darknet")
# !sed -i 's/batch=1/batch=64/g' cfg/yolov3.cfg
# !sed -i 's/subdivisions=1/subdivisions=32/g' cfg/yolov3.cfg
# !sed -i 's/max_batches = 500200/max_batches = 5000/g' cfg/yolov3.cfg
# !sed -i 's/steps=400000,450000/steps=4000,5000/g' cfg/yolov3.cfg
# !sed -i 's/classes=80/classes=5/g' cfg/yolov3.cfg
# !sed -i 's/filters=255/filters=30/g' cfg/yolov3.cfg
# !cat cfg/yolov3.cfg
# Out:
# [net]
# # Testing
# batch=64
# subdivisions=32
# # Training
# # batch=64
# # subdivisions=326
# width=416
# height=416
# channels=3
# momentum=0.9
# decay=0.0005
# angle=0
# saturation = 1.5
# exposure = 1.5
# hue=.1
#
# learning_rate=0.001
# burn_in=1000
# max_batches = 5000
# policy=steps
# steps=4000,5000
# scales=.1,.1
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=3
# stride=1
# pad=1
# activation=leaky
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=32
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=64
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# # Downsample
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=2
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=1024
# size=3
# stride=1
# pad=1
# activation=leaky
#
# [shortcut]
# from=-3
# activation=linear
#
# ######################
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=512
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=1024
# activation=leaky
#
# [convolutional]
# size=1
# stride=1
# pad=1
# filters=30
# activation=linear
#
#
# [yolo]
# mask = 6,7,8
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=5
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
#
#
# [route]
# layers = -4
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [upsample]
# stride=2
#
# [route]
# layers = -1, 61
#
#
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=256
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=512
# activation=leaky
#
# [convolutional]
# size=1
# stride=1
# pad=1
# filters=30
# activation=linear
#
#
# [yolo]
# mask = 3,4,5
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=5
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1
#
#
#
# [route]
# layers = -4
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [upsample]
# stride=2
#
# [route]
# layers = -1, 36
#
#
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# filters=128
# size=1
# stride=1
# pad=1
# activation=leaky
#
# [convolutional]
# batch_normalize=1
# size=3
# stride=1
# pad=1
# filters=256
# activation=leaky
#
# [convolutional]
# size=1
# stride=1
# pad=1
# filters=30
# activation=linear
#
#
# [yolo]
# mask = 0,1,2
# anchors = 10,13,  16,30,  33,23,  30,61,  62,45,  59,119,  116,90,  156,198,  373,326
# classes=5
# num=9
# jitter=.3
# ignore_thresh = .7
# truth_thresh = 1
# random=1

# %% [markdown]
# ## Train the yolo model with new dataset

# %%
os.chdir("/content/darknet")
# use the line below to retrain your previous saved weight
# !./darknet detector train data/obj.data cfg/yolov3.cfg darknet53.conv.74
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.160031), count: 1, class_loss = 315.923096, iou_loss = 3.771637, total_loss = 319.694733
#  total_bbox = 18123, rewritten_bbox = 0.160018 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 43.593193, iou_loss = 0.000000, total_loss = 43.593193
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.366775), count: 2, class_loss = 144.654739, iou_loss = 3.208267, total_loss = 147.863007
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.449749), count: 3, class_loss = 309.467896, iou_loss = 3.157104, total_loss = 312.625000
#  total_bbox = 18128, rewritten_bbox = 0.159974 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 44.025440, iou_loss = 0.000000, total_loss = 44.025440
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.376925), count: 5, class_loss = 149.727158, iou_loss = 6.621552, total_loss = 156.348709
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.333512), count: 1, class_loss = 312.096741, iou_loss = 1.362000, total_loss = 313.458740
#  total_bbox = 18134, rewritten_bbox = 0.159921 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 44.426254, iou_loss = 0.000000, total_loss = 44.426254
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.408154), count: 3, class_loss = 147.266510, iou_loss = 4.675339, total_loss = 151.941849
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.302308), count: 4, class_loss = 320.158539, iou_loss = 9.260742, total_loss = 329.419281
#  total_bbox = 18141, rewritten_bbox = 0.159859 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss =
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.367873), count: 3, class_loss = 36.885517, iou_loss = 4.434162, total_loss = 41.319679
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.494683), count: 1, class_loss = 32.557098, iou_loss = 0.878628, total_loss = 33.435726
#  total_bbox = 24626, rewritten_bbox = 0.150248 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.379238), count: 2, class_loss = 24.259373, iou_loss = 2.513367, total_loss = 26.772739
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.333858), count: 2, class_loss = 33.290401, iou_loss = 2.162441, total_loss = 35.452843
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.550972), count: 2, class_loss = 31.157328, iou_loss = 1.051386, total_loss = 32.208714
#  total_bbox = 24632, rewritten_bbox = 0.150211 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 22.374699, iou_loss = 0.000000, total_loss = 22.374699
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.394638), count: 1, class_loss = 32.493202, iou_loss = 0.690155, total_loss = 33.183357
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.412584), count: 1, class_loss = 33.581783, iou_loss = 0.466480, total_loss = 34.048264
#  total_bbox = 24634, rewritten_bbox = 0.150199 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.494967), count: 1, class_loss = 23.119848, iou_loss = 0.513275, total_loss = 23.633123
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.256328), count: 2, class_loss = 35.645996, iou_loss = 5.256378, total_loss = 40.902374
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 32.784691, iou_loss = 0.000000, total_loss = 32.784691
#  total_bbox = 24637, rewritten_bbox = 0.150181 %
#
#  143: 33.105141, 88.495834 avg loss, 0.000000 rate, 4.716200 seconds, 9152 images, 10.534131 hours left
# Loaded: 0.000043 seconds
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.404460), count: 1, class_loss = 21.774313, iou_loss = 0.776785, total_loss = 22.551098
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.280565), count: 3, class_loss = 34.807331, iou_loss = 10.912369, total_loss = 45.719700
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.472941), count: 2, class_loss = 32.884384, iou_loss = 1.168316, total_loss = 34.052700
#  total_bbox = 24643, rewritten_bbox = 0.150144 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.299896), count: 3, class_loss = 24.633677, iou_loss = 3.029432, total_loss = 27.663109
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.278171), count: 1, class_loss = 31.523251, iou_loss = 2.038410, total_loss = 33.561661
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.000000), count: 1, class_loss = 27.922131, iou_loss = 0.000000, total_loss = 27.922131
#  total_bbox = 24647, rewritten_bbox = 0.150120 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.000000), count: 1, class_loss = 21.245852, iou_loss = 0.000000, total_loss = 21.245852
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.445866), count: 2, class_loss = 32.886490, iou_loss = 2.297489, total_loss = 35.183979
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.299084), count: 4, class_loss = 32.967083, iou_loss = 4.165035, total_loss = 37.132118
#  total_bbox = 24653, rewritten_bbox = 0.150083 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.442874), count: 2, class_loss = 23.670530, iou_loss = 1.271650, total_loss = 24.942181
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.404066), count: 4, class_loss = 34.873589, iou_loss = 4.289024, total_loss = 39.162613
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.348582), count: 2, class_loss = 30.026022, iou_loss = 2.147474, total_loss = 32.173496
#  total_bbox = 24661, rewritten_bbox = 0.150034 %
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 82 Avg (IOU: 0.700893), count: 1, class_loss = 22.793213, iou_loss = 0.134420, total_loss = 22.927633
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 94 Avg (IOU: 0.331331), count: 5, class_loss = 38.710358, iou_loss = 10.190857, total_loss = 48.901215
# v3 (mse loss, Normalizer: (iou: 0.75, obj: 1.00, cls: 1.00) Region 106 Avg (IOU: 0.459223), count: 1, class_loss = 33.210098, iou_loss = 0.602905, total_loss = 33.813004
# ^C

# %%
os.chdir("/content/darknet")
# !wget -q https://cdn.pixabay.com/photo/2016/09/13/16/21/colorful-1667624_960_720.jpg

# %%
os.chdir("/content/darknet")

# %%
import cv2
import matplotlib.pyplot as plt

# %%
import numpy as np
import argparse
import time
import cv2
import os

img_name = "colorful-1667624_960_720.jpg"
confidence_val = 0.6 # for confidence filtering of object detection
threshold = 0.4 # for NMS

LABELS = open("data/obj.names").read().strip().split("\n")
# initialize a list of colors to represent each possible class label
np.random.seed(42)
COLORS = np.random.randint(0, 255, size=(len(LABELS), 3),dtype="uint8")
print(LABELS)
# derive the paths to the YOLO weights and model configuration
weightsPath = "backup/yolov3_last.weights"
configPath = "cfg/yolov3.cfg"
# load our YOLO object detector trained on COCO dataset (80 classes)
print("[INFO] loading YOLO from disk...")
net = cv2.dnn.readNetFromDarknet(configPath, weightsPath)

image = cv2.imread(img_name)
(H, W) = image.shape[:2]
# determine only the *output* layer names that we need from YOLO
ln = net.getLayerNames()
ln = [ln[i[0] - 1] for i in net.getUnconnectedOutLayers()]
# construct a blob from the input image and then perform a forward
# pass of the YOLO object detector, giving us our bounding boxes and
# associated probabilities
blob = cv2.dnn.blobFromImage(image, 1 / 255.0, (416, 416),
	swapRB=True, crop=False)
net.setInput(blob)
start = time.time()
layerOutputs = net.forward(ln)
end = time.time()
# show timing information on YOLO
print("[INFO] YOLO took {:.6f} seconds".format(end - start))
# initialize our lists of detected bounding boxes, confidences, and
# class IDs, respectively
boxes = []
confidences = []
classIDs = []


# loop over each of the layer outputs
for output in layerOutputs:
	# loop over each of the detections
	for detection in output:
		# extract the class ID and confidence (i.e., probability) of
		# the current object detection
		scores = detection[5:]
		classID = np.argmax(scores)
		confidence = scores[classID]
		# filter out weak predictions by ensuring the detected
		# probability is greater than the minimum probability
		if confidence > confidence_val:
			# scale the bounding box coordinates back relative to the
			# size of the image, keeping in mind that YOLO actually
			# returns the center (x, y)-coordinates of the bounding
			# box followed by the boxes' width and height
			box = detection[0:4] * np.array([W, H, W, H])
			(centerX, centerY, width, height) = box.astype("int")
			# use the center (x, y)-coordinates to derive the top and
			# and left corner of the bounding box
			x = int(centerX - (width / 2))
			y = int(centerY - (height / 2))
			# update our list of bounding box coordinates, confidences,
			# and class IDs
			boxes.append([x, y, int(width), int(height)])
			confidences.append(float(confidence))
			classIDs.append(classID)
   
# apply non-maxima suppression to suppress weak, overlapping bounding
# boxes
idxs = cv2.dnn.NMSBoxes(boxes, confidences, confidence_val,threshold)

# ensure at least one detection exists
if len(idxs) > 0:
	# loop over the indexes we are keeping
	for i in idxs.flatten():
		# extract the bounding box coordinates
		(x, y) = (boxes[i][0], boxes[i][1])
		(w, h) = (boxes[i][2], boxes[i][3])
		# draw a bounding box rectangle and label on the image
		color = [int(c) for c in COLORS[classIDs[i]]]
		cv2.rectangle(image, (x, y), (x + w, y + h), color, 2)
		text = "{}: {:.4f}".format(LABELS[classIDs[i]], confidences[i])
		cv2.putText(image, text, (x, y - 5), cv2.FONT_HERSHEY_SIMPLEX,
			0.5, color, 2)
# show the output image
plt.imshow(image)
# Out:
# ['Tug', 'Ferry', 'Sailboat', 'Cruise', 'Unknown']
# [INFO] loading YOLO from disk...
# [INFO] YOLO took 1.646674 seconds

# %%
plt.figure(figsize=(16,10))
plt.imshow(image)
plt.show()
